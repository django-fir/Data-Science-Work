# %%
import requests
import json
from pprint import pprint
from datetime import datetime as dt

# %%
def convert(data):  
  data['name'] = geo_data["name"]
  data["zip"] = geo_data["zip"]
  rise,sett,zone = data['sys']["sunrise"],data['sys']["sunset"],data["timezone"]
  data['sys']["sunrise"],data['sys']["sunset"],data["timezone"] = dt.fromtimestamp(rise),dt.fromtimestamp(sett),dt.fromtimestamp(zone)

# %%
api_key = "e660d5c17527a3b8bed8329cd9898050"
# api_key = "53bedead133fcccd5a6c72667049ff25"

# %%
limit = 10

# %%
city_name = "Bangalore"

# %%
zip_code = "560034"
country_code = "In"

# %%
geo_url = f"http://api.openweathermap.org/geo/1.0/direct?q={city_name}&limit={limit}&appid={api_key}"
zip_url = f"http://api.openweathermap.org/geo/1.0/zip?zip={zip_code},{country_code}&appid={api_key}"
response = requests.get(zip_url)
print(response.status_code)
# print(response.json())

# %%
geo_data = response.json()
pprint(geo_data)
# op = int(input(":>"))

# %%
def get_cord(data):
  return geo_data["lat"],geo_data["lon"]

# %%
lat,lon = get_cord(geo_data)

# %%
print((lat,lon))
# lat,lon = "13.3289","78.1682"

# %%
# weather_url = f"https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid={api_key}"
forcast_url = f"https://api.openweathermap.org/data/2.5/forecast?lat={lat}&lon={lon}&appid={api_key}"

# %%
def display(d):
  pprint(d['city'])
  print("\n")  
  for i in d['list']:
    print(f"Date  : {i.get('dt_txt')} : \n")
    for j in [i['main'],i['weather'],i['wind']]:
      pprint(j)
      print("\n")
    print()

# %%
response = requests.get(forcast_url)
data = response.json()
display(data)
# pprint(data)
