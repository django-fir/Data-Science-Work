# %%
from google.colab import files

# %%
files.upload()

# %%
# !mkdir ~/.kaggle

# %%
# !cp kaggle.json ~/.kaggle

# %%
! chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle competitions download -c quora-question-pairs

# %%
# !mkdir train

# %%
# !unzip /content/quora-question-pairs.zip

# %%
# !unzip /content/train.csv.zip

# %%
# !unzip /content/test.csv.zip

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import plotly.express as px
import plotly.graph_objects as go

# %%
df = pd.read_csv('/content/train.csv')
print("shpae : ",df.shape[0])

# %%
df.head()

# %%
df["is_duplicate"].value_counts()

# %%
px.histogram(df,x="is_duplicate",barmode="group")

# %%
df.groupby('is_duplicate')['id'].count().plot.bar()

# %%
print("questions pair similar {}%".format(100-round(df["is_duplicate"].mean()*100),2))
print("questions pair not  similar {}%".format(round(df["is_duplicate"].mean()*100),2))

# %%
qids = pd.Series(df['qid1'].tolist()+df['qid2'].tolist())
uqids = len(qids.unique())
rqids = sum(qids.value_counts() > 1)
print("unique: {}".format(uqids))
print("repeted more than once {} ({}%)".format(rqids,rqids/uqids*100))
print("max repitations {}".format(qids.value_counts().max()))

# %%
x = ["unique","repeted"]
y = [uqids,rqids]
px.
