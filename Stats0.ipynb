# %%
from scipy.stats import binom,norm

# %%
a = 0
b = 1-(19/20)**10
for i in range(1,21):
  a+=binom.pmf(p=b,n=20,k=i)*i
a
# Out:
# 8.02526121523242

# %%
b*20
# Out:
# 8.025261215232426

# %%
((6/7)**3)*(1-(6/7)**3)
# Out:
# 0.2332

# %%
((6/7)**3) * ()
# Out:
# 0.07894669737949321

# %%
binom.pmf(p=6/7,n=3,k=3)*(binom.cdf(p=1/7,n=3,k=3) - binom.cdf(p=1/7,n=3,k=0))
# Out:
# 0.23316815272548005

# %%
55*(1/20)
# Out:
# 2.75

# %%
binom.pmf(p=0.7,n=5,k=3)
# Out:
# 0.30869999999999986

# %%
1/3/(1/3p)

# %%
a=norm.cdf(loc=27,scale=7,x=20)
a
# Out:
# 0.15865525393145707

# %%
b=norm.cdf(loc=27,scale=7,x=14)
b
# Out:
# 0.031645416116672626

# %%
(a-b)*10000
# Out:
# 1270.0983781478444
