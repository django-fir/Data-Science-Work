# %% [markdown]
# ### ***Mini Case Study (fitbit)***

# %%
import numpy as np
import plotly.express as px
import seaborn as sns

# %%
np.loadtxt('https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/039/649/original/olympics.csv?1689050368',delimiter=',')

# %%
#loading the Text File
fit = np.genfromtxt("fit.txt",dtype=[('date','U20'),('step_count',int),('mood','U20'),('calories_burned',int),('hours_of_sleep',int),('active','U20')])
fit

# %%
np.savetxt('fit_bit.csv', fit,fmt = '%s,%d,%s,%d,%d,%s', delimiter=',')

# %%
#Columns Of Our Data
col = fit.dtype.names
col

# %%
fit.shape

# %%
np.unique(fit['date']).shape

# %% [markdown]
# ## ***What are the average daily steps taken by users?***

# %%
fit['step_count'].mean()

# %%
fig = px.histogram(x=fit['step_count'], nbins=50, histnorm='probability density')
fig.show()

# %%
fig = sns.distplot(x=fit['step_count'])
fig

# %% [markdown]
# week by week
