# %%
        <div class="contact-boxright mbottom delivery-rightgreybox">
            <h5 class="right-titlebox">Sri Venkateshwara Enterprises</h5>
            <div class="icon-with-left">
                <img src="/Content/assets/images/delivery-center/map-pin.png" />
                <p class="black-color"> M. G. Road <Br> Srinivaspura,- 563135</p>
            </div>
            <div class="more-detail-contact">
                <p><b class="fw-500">Mobile Number -</b>  <span class="fw-400">9880992077</span></p>
            </div>
                <a href="javascript:getMapDirection(13.33051, 78.20774,'Sri Venkateshwara Enterprises');" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=13.33051,78.20774" target="_blank" class="getdirectin"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=13.33051,78.20774" target="_self" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <span class="lat d-none">13.33051</span>
                <span class="lng d-none">78.20774</span>
            <a class="puc-store">Puc</a>
        </div>
        <div class="contact-boxright mbottom delivery-rightgreybox">
            <h5 class="right-titlebox">Sri Raghavendra Rcm Bazar</h5>
            <div class="icon-with-left">
                <img src="/Content/assets/images/delivery-center/map-pin.png" />
                <p class="black-color"> Near Police Station <Br> Vemagal,- 563102</p>
            </div>
            <div class="more-detail-contact">
                <p><b class="fw-500">Mobile Number -</b>  <span class="fw-400">9972000970</span></p>
            </div>
                <a href="javascript:getMapDirection(13.19252, 78.01811,'Sri Raghavendra Rcm Bazar');" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=13.19252,78.01811" target="_blank" class="getdirectin"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=13.19252,78.01811" target="_self" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <span class="lat d-none">13.19252</span>
                <span class="lng d-none">78.01811</span>
            <a class="puc-store">Puc</a>
        </div>
        <div class="contact-boxright mbottom delivery-rightgreybox">
            <h5 class="right-titlebox">Chandana Traders</h5>
            <div class="icon-with-left">
                <img src="/Content/assets/images/delivery-center/map-pin.png" />
                <p class="black-color"> Urban Bank Building, Near Sharada Talkies  <Br> Kolar,- 563101</p>
            </div>
            <div class="more-detail-contact">
                <p><b class="fw-500">Mobile Number -</b>  <span class="fw-400">9972310331</span></p>
            </div>
                <a href="javascript:getMapDirection(13.13514, 78.12891,'Chandana Traders');" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=13.13514,78.12891" target="_blank" class="getdirectin"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=13.13514,78.12891" target="_self" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <span class="lat d-none">13.13514</span>
                <span class="lng d-none">78.12891</span>
            <a class="puc-store">Puc</a>
        </div>
        <div class="contact-boxright mbottom delivery-rightgreybox">
            <h5 class="right-titlebox">M N S Swadeshi Uthpannagala Malige</h5>
            <div class="icon-with-left">
                <img src="/Content/assets/images/delivery-center/map-pin.png" />
                <p class="black-color"> Manjunatha Comlpex, Mc Road <Br> Mulabagaul,- 563131</p>
            </div>
            <div class="more-detail-contact">
                <p><b class="fw-500">Mobile Number -</b>  <span class="fw-400">9141377488</span></p>
            </div>
                <a href="javascript:getMapDirection(13.16665, 78.39407,'M N S Swadeshi Uthpannagala Malige');" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=13.16665,78.39407" target="_blank" class="getdirectin"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=13.16665,78.39407" target="_self" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <span class="lat d-none">13.16665</span>
                <span class="lng d-none">78.39407</span>
            <a class="puc-store">Puc</a>
        </div>
        <div class="contact-boxright mbottom delivery-rightgreybox">
            <h5 class="right-titlebox">Nidhi Rcm Mart </h5>
            <div class="icon-with-left">
                <img src="/Content/assets/images/delivery-center/map-pin.png" />
                <p class="black-color"> Shop No.3, Door No.1629/1, Dandu Road, Opp Venkateswra Best School <Br> Bangarpet ,- 563114</p>
            </div>
            <div class="more-detail-contact">
                <p><b class="fw-500">Mobile Number -</b>  <span class="fw-400">9448342114</span></p>
            </div>
                <a href="javascript:getMapDirection(25, 75,'Nidhi Rcm Mart ');" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=25,75" target="_blank" class="getdirectin"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=25,75" target="_self" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <span class="lat d-none">25</span>
                <span class="lng d-none">75</span>
            <a class="puc-store">Puc</a>
        </div>
        <div class="contact-boxright mbottom delivery-rightgreybox">
            <h5 class="right-titlebox">Sri Sai Lakshmi Key Soul Outlate </h5>
            <div class="icon-with-left">
                <img src="/Content/assets/images/delivery-center/map-pin.png" />
                <p class="black-color"> Main Road <Br> Thathipalya,- 563131</p>
            </div>
            <div class="more-detail-contact">
                <p><b class="fw-500">Mobile Number -</b>  <span class="fw-400">8105888359</span></p>
            </div>
                <a href="javascript:getMapDirection(13.176294231124915, 78.39083720652546,'Sri Sai Lakshmi Key Soul Outlate ');" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=13.176294231124915,78.39083720652546" target="_blank" class="getdirectin"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=13.176294231124915,78.39083720652546" target="_self" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <span class="lat d-none">13.176294231124915</span>
                <span class="lng d-none">78.39083720652546</span>
            <a class="puc-store">Keysoul Outlet</a>
        </div>

# %%
        <div class="contact-boxright mbottom delivery-rightgreybox">
            <h5 class="right-titlebox">Sri Chowdeshwary Rcm Bazar</h5>
            <div class="icon-with-left">
                <img src="/Content/assets/images/delivery-center/map-pin.png" />
                <p class="black-color"> .. <Br> H Cross,- 562102</p>
            </div>
            <div class="more-detail-contact">
                <p><b class="fw-500">Mobile Number -</b>  <span class="fw-400">9901683244</span></p>
            </div>
                <a href="javascript:getMapDirection(13.24259, 77.93067,'Sri Chowdeshwary Rcm Bazar');" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=13.24259,77.93067" target="_blank" class="getdirectin"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=13.24259,77.93067" target="_self" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <span class="lat d-none">13.24259</span>
                <span class="lng d-none">77.93067</span>
            <a class="puc-store">Puc</a>
        </div>
        <div class="contact-boxright mbottom delivery-rightgreybox">
            <h5 class="right-titlebox">Manoj Swadeshi Bhandara</h5>
            <div class="icon-with-left">
                <img src="/Content/assets/images/delivery-center/map-pin.png" />
                <p class="black-color"> Bvm Choultry <Br> Timmasandra- Chintamani,- 563125</p>
            </div>
            <div class="more-detail-contact">
                <p><b class="fw-500">Mobile Number -</b>  <span class="fw-400">9945127157</span></p>
            </div>
                <a href="javascript:getMapDirection(13.40691, 78.03737,'Manoj Swadeshi Bhandara');" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=13.40691,78.03737" target="_blank" class="getdirectin"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=13.40691,78.03737" target="_self" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <span class="lat d-none">13.40691</span>
                <span class="lng d-none">78.03737</span>
            <a class="puc-store">Puc</a>
        </div>
        <div class="contact-boxright mbottom delivery-rightgreybox">
            <h5 class="right-titlebox">Right Concept Marketing</h5>
            <div class="icon-with-left">
                <img src="/Content/assets/images/delivery-center/map-pin.png" />
                <p class="black-color"> Shop No.28, Pcr Complex, Mg Road <Br> Chintamani,- 563125</p>
            </div>
            <div class="more-detail-contact">
                <p><b class="fw-500">Mobile Number -</b>  <span class="fw-400">7892248624</span></p>
            </div>
                <a href="javascript:getMapDirection(13.4019689, 78.0551384,'Right Concept Marketing');" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=13.4019689,78.0551384" target="_blank" class="getdirectin"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=13.4019689,78.0551384" target="_self" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <span class="lat d-none">13.4019689</span>
                <span class="lng d-none">78.0551384</span>
            <a class="puc-store">Puc</a>
        </div>
        <div class="contact-boxright mbottom delivery-rightgreybox">
            <h5 class="right-titlebox">Lakshmi Venkateswara Rcm Mart</h5>
            <div class="icon-with-left">
                <img src="/Content/assets/images/delivery-center/map-pin.png" />
                <p class="black-color"> Peresandra Cross <Br> Peresandra,- 562101</p>
            </div>
            <div class="more-detail-contact">
                <p><b class="fw-500">Mobile Number -</b>  <span class="fw-400">7204388948</span></p>
            </div>
                <a href="javascript:getMapDirection(13.5873005690511, 77.7867024644038,'Lakshmi Venkateswara Rcm Mart');" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=13.5873005690511,77.7867024644038" target="_blank" class="getdirectin"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=13.5873005690511,77.7867024644038" target="_self" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <span class="lat d-none">13.5873005690511</span>
                <span class="lng d-none">77.7867024644038</span>
            <a class="puc-store">Wonder World Quick</a>
        </div>
        <div class="contact-boxright mbottom delivery-rightgreybox">
            <h5 class="right-titlebox">Sri Vanajakshi New Enterprises</h5>
            <div class="icon-with-left">
                <img src="/Content/assets/images/delivery-center/map-pin.png" />
                <p class="black-color"> 1st Coss, N R Extention, Ear Mysore Hospital Road <Br> Chintamani,- 563125</p>
            </div>
            <div class="more-detail-contact">
                <p><b class="fw-500">Mobile Number -</b>  <span class="fw-400">9663009751</span></p>
            </div>
                <a href="javascript:getMapDirection(13.3977917, 78.0544946,'Sri Vanajakshi New Enterprises');" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=13.3977917,78.0544946" target="_blank" class="getdirectin"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=13.3977917,78.0544946" target="_self" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <span class="lat d-none">13.3977917</span>
                <span class="lng d-none">78.0544946</span>
            <a class="puc-store">Wonder World Quick</a>
        </div>
        <div class="contact-boxright mbottom delivery-rightgreybox">
            <h5 class="right-titlebox">Sri Chowdeswari Rcm Mart</h5>
            <div class="icon-with-left">
                <img src="/Content/assets/images/delivery-center/map-pin.png" />
                <p class="black-color"> Opp. Sjcit  <Br> Agalagurki,- 562103</p>
            </div>
            <div class="more-detail-contact">
                <p><b class="fw-500">Mobile Number -</b>  <span class="fw-400">9880916806</span></p>
            </div>
                <a href="javascript:getMapDirection(13.4134698918187, 77.7395528782038,'Sri Chowdeswari Rcm Mart');" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=13.4134698918187,77.7395528782038" target="_blank" class="getdirectin"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=13.4134698918187,77.7395528782038" target="_self" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <span class="lat d-none">13.4134698918187</span>
                <span class="lng d-none">77.7395528782038</span>
            <a class="puc-store">Wonder World Quick</a>
        </div>
        <div class="contact-boxright mbottom delivery-rightgreybox">
            <h5 class="right-titlebox">Maruthi Key Soul Store</h5>
            <div class="icon-with-left">
                <img src="/Content/assets/images/delivery-center/map-pin.png" />
                <p class="black-color"> Chnnabasppa Compound, N R Extension  <Br> Chintamnai,- 563125</p>
            </div>
            <div class="more-detail-contact">
                <p><b class="fw-500">Mobile Number -</b>  <span class="fw-400">9902592716</span></p>
            </div>
                <a href="javascript:getMapDirection(13.4019689, 78.0551384,'Maruthi Key Soul Store');" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=13.4019689,78.0551384" target="_blank" class="getdirectin"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=13.4019689,78.0551384" target="_self" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <span class="lat d-none">13.4019689</span>
                <span class="lng d-none">78.0551384</span>
            <a class="puc-store">Keysoul Outlet</a>
        </div>
        <div class="contact-boxright mbottom delivery-rightgreybox">
            <h5 class="right-titlebox">V S Enterprises</h5>
            <div class="icon-with-left">
                <img src="/Content/assets/images/delivery-center/map-pin.png" />
                <p class="black-color"> Jangamakote Cross <Br> Jangamakote,- 562102</p>
            </div>
            <div class="more-detail-contact">
                <p><b class="fw-500">Mobile Number -</b>  <span class="fw-400">6362321547</span></p>
            </div>
                <a href="javascript:getMapDirection(13.2553623, 77.8495921,'V S Enterprises');" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=13.2553623,77.8495921" target="_blank" class="getdirectin"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=13.2553623,77.8495921" target="_self" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <span class="lat d-none">13.2553623</span>
                <span class="lng d-none">77.8495921</span>
            <a class="puc-store">Wonder World Quick</a>
        </div>
        <div class="contact-boxright mbottom delivery-rightgreybox">
            <h5 class="right-titlebox">Devika Key Soul</h5>
            <div class="icon-with-left">
                <img src="/Content/assets/images/delivery-center/map-pin.png" />
                <p class="black-color"> 1st Cross, H B N Serviece Station  <Br> Chintamani,- 563125</p>
            </div>
            <div class="more-detail-contact">
                <p><b class="fw-500">Mobile Number -</b>  <span class="fw-400">7483380259</span></p>
            </div>
                <a href="javascript:getMapDirection(13.4019689, 78.0551384,'Devika Key Soul');" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=13.4019689,78.0551384" target="_blank" class="getdirectin"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=13.4019689,78.0551384" target="_self" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <span class="lat d-none">13.4019689</span>
                <span class="lng d-none">78.0551384</span>
            <a class="puc-store">Keysoul Outlet</a>
        </div>
        <div class="contact-boxright mbottom delivery-rightgreybox">
            <h5 class="right-titlebox">Sri Lakshmivenkateshwara Key Soul</h5>
            <div class="icon-with-left">
                <img src="/Content/assets/images/delivery-center/map-pin.png" />
                <p class="black-color"> Main Road <Br> Madabahalli,- 563128</p>
            </div>
            <div class="more-detail-contact">
                <p><b class="fw-500">Mobile Number -</b>  <span class="fw-400">8217569241</span></p>
            </div>
                <a href="javascript:getMapDirection(13.3090552, 78.0088357,'Sri Lakshmivenkateshwara Key Soul');" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=13.3090552,78.0088357" target="_blank" class="getdirectin"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=13.3090552,78.0088357" target="_self" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <span class="lat d-none">13.3090552</span>
                <span class="lng d-none">78.0088357</span>
            <a class="puc-store">Keysoul Outlet</a>
        </div>

# %%
        <div class="contact-boxright mbottom delivery-rightgreybox">
            <h5 class="right-titlebox">Shree Veerabadhreshwar Rcm Bazar</h5>
            <div class="icon-with-left">
                <img src="/Content/assets/images/delivery-center/map-pin.png" />
                <p class="black-color"> 54, 11th Cross, Acl Layout, Kalkere Main Road <Br> Bangalore- Ramamurthy Nagar,- 560016</p>
            </div>
            <div class="more-detail-contact">
                <p><b class="fw-500">Mobile Number -</b>  <span class="fw-400">9008125426</span></p>
            </div>
                <a href="javascript:getMapDirection(13.0163, 77.6749,'Shree Veerabadhreshwar Rcm Bazar');" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=13.0163,77.6749" target="_blank" class="getdirectin"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=13.0163,77.6749" target="_self" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <span class="lat d-none">13.0163</span>
                <span class="lng d-none">77.6749</span>
            <a class="puc-store">Wonder World Quick</a>
        </div>
        <div class="contact-boxright mbottom delivery-rightgreybox">
            <h5 class="right-titlebox">Star Rcm Puc</h5>
            <div class="icon-with-left">
                <img src="/Content/assets/images/delivery-center/map-pin.png" />
                <p class="black-color"> No.8/2, 26th Main, 39th Cross, Jayanagar 9th Block, Near M. K. Ahmed Bazar, Ssmrv College Road  <Br> Bangalore,- 560069</p>
            </div>
            <div class="more-detail-contact">
                <p><b class="fw-500">Mobile Number -</b>  <span class="fw-400">8123872361</span></p>
            </div>
                <a href="javascript:getMapDirection(12.92046, 77.59203,'Star Rcm Puc');" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=12.92046,77.59203" target="_blank" class="getdirectin"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=12.92046,77.59203" target="_self" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <span class="lat d-none">12.92046</span>
                <span class="lng d-none">77.59203</span>
            <a class="puc-store">Puc</a>
        </div>
        <div class="contact-boxright mbottom delivery-rightgreybox">
            <h5 class="right-titlebox">Sri Kalki Annapurneshwari Traders</h5>
            <div class="icon-with-left">
                <img src="/Content/assets/images/delivery-center/map-pin.png" />
                <p class="black-color"> C- 2-153, Doc Housing Colony, Behind J.b. Nagar, Police Station <Br> Bangalore,- 560075</p>
            </div>
            <div class="more-detail-contact">
                <p><b class="fw-500">Mobile Number -</b>  <span class="fw-400">9141183458</span></p>
            </div>
                <a href="javascript:getMapDirection(12.964469800000, 77.657500900000,'Sri Kalki Annapurneshwari Traders');" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=12.964469800000,77.657500900000" target="_blank" class="getdirectin"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=12.964469800000,77.657500900000" target="_self" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <span class="lat d-none">12.964469800000</span>
                <span class="lng d-none">77.657500900000</span>
            <a class="puc-store">Puc</a>
        </div>
        <div class="contact-boxright mbottom delivery-rightgreybox">
            <h5 class="right-titlebox">Health And Natural Rcm Bazar</h5>
            <div class="icon-with-left">
                <img src="/Content/assets/images/delivery-center/map-pin.png" />
                <p class="black-color"> No.75, 4th Cross, Singapura Main Road <Br> Ms Palaya- Bangalore,- 560095</p>
            </div>
            <div class="more-detail-contact">
                <p><b class="fw-500">Mobile Number -</b>  <span class="fw-400">9341322770</span></p>
            </div>
                <a href="javascript:getMapDirection(13.08146, 77.54833,'Health And Natural Rcm Bazar');" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=13.08146,77.54833" target="_blank" class="getdirectin"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=13.08146,77.54833" target="_self" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <span class="lat d-none">13.08146</span>
                <span class="lng d-none">77.54833</span>
            <a class="puc-store">Puc</a>
        </div>
        <div class="contact-boxright mbottom delivery-rightgreybox">
            <h5 class="right-titlebox">Kamal Enterprises</h5>
            <div class="icon-with-left">
                <img src="/Content/assets/images/delivery-center/map-pin.png" />
                <p class="black-color"> No.-1324/384, 16th Cross . Pipeline Hoysalanagar <Br> Bangalore,- 560091</p>
            </div>
            <div class="more-detail-contact">
                <p><b class="fw-500">Mobile Number -</b>  <span class="fw-400">9342901980</span></p>
            </div>
                <a href="javascript:getMapDirection(12.99202, 77.50550,'Kamal Enterprises');" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=12.99202,77.50550" target="_blank" class="getdirectin"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=12.99202,77.50550" target="_self" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <span class="lat d-none">12.99202</span>
                <span class="lng d-none">77.50550</span>
            <a class="puc-store">Puc</a>
        </div>
        <div class="contact-boxright mbottom delivery-rightgreybox">
            <h5 class="right-titlebox">Vista Rcm Bazar</h5>
            <div class="icon-with-left">
                <img src="/Content/assets/images/delivery-center/map-pin.png" />
                <p class="black-color"> #-79, Vista 2nd Main Road, R. J. Garden <Br> Bangalore- Marathahalli,- 560037</p>
            </div>
            <div class="more-detail-contact">
                <p><b class="fw-500">Mobile Number -</b>  <span class="fw-400">8892609961</span></p>
            </div>
                <a href="javascript:getMapDirection(12.95917, 77.69742,'Vista Rcm Bazar');" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=12.95917,77.69742" target="_blank" class="getdirectin"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=12.95917,77.69742" target="_self" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <span class="lat d-none">12.95917</span>
                <span class="lng d-none">77.69742</span>
            <a class="puc-store">Puc</a>
        </div>
        <div class="contact-boxright mbottom delivery-rightgreybox">
            <h5 class="right-titlebox">Yashas Associates</h5>
            <div class="icon-with-left">
                <img src="/Content/assets/images/delivery-center/map-pin.png" />
                <p class="black-color"> K H No: 425/8, Muniyaoda Building, Sadhara Beedi <Br> Attibele,- 562107</p>
            </div>
            <div class="more-detail-contact">
                <p><b class="fw-500">Mobile Number -</b>  <span class="fw-400">9036345746</span></p>
            </div>
                <a href="javascript:getMapDirection(12.78071, 77.77095,'Yashas Associates');" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=12.78071,77.77095" target="_blank" class="getdirectin"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=12.78071,77.77095" target="_self" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <span class="lat d-none">12.78071</span>
                <span class="lng d-none">77.77095</span>
            <a class="puc-store">Puc</a>
        </div>
        <div class="contact-boxright mbottom delivery-rightgreybox">
            <h5 class="right-titlebox">Sunshine Rcm Bazar</h5>
            <div class="icon-with-left">
                <img src="/Content/assets/images/delivery-center/map-pin.png" />
                <p class="black-color"> No.226, 1st Main Road, Kempegowda Nagar <Br> Bangalore- T. Dasarahalli,- 560057</p>
            </div>
            <div class="more-detail-contact">
                <p><b class="fw-500">Mobile Number -</b>  <span class="fw-400">9008653916</span></p>
            </div>
                <a href="javascript:getMapDirection(13.05021, 77.51193,'Sunshine Rcm Bazar');" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=13.05021,77.51193" target="_blank" class="getdirectin"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=13.05021,77.51193" target="_self" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <span class="lat d-none">13.05021</span>
                <span class="lng d-none">77.51193</span>
            <a class="puc-store">Wonder World Quick</a>
        </div>
        <div class="contact-boxright mbottom delivery-rightgreybox">
            <h5 class="right-titlebox">Mona Enterprises</h5>
            <div class="icon-with-left">
                <img src="/Content/assets/images/delivery-center/map-pin.png" />
                <p class="black-color"> 35, 6th, B- Cross, 2nd Main, Chowdeshwari Nagar <Br> Bangalore- Laggere,- 560058</p>
            </div>
            <div class="more-detail-contact">
                <p><b class="fw-500">Mobile Number -</b>  <span class="fw-400">8618001213</span></p>
            </div>
                <a href="javascript:getMapDirection(13.00251, 77.52059,'Mona Enterprises');" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=13.00251,77.52059" target="_blank" class="getdirectin"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=13.00251,77.52059" target="_self" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <span class="lat d-none">13.00251</span>
                <span class="lng d-none">77.52059</span>
            <a class="puc-store">Puc</a>
        </div>
        <div class="contact-boxright mbottom delivery-rightgreybox">
            <h5 class="right-titlebox">Shiva Divine Enterprises</h5>
            <div class="icon-with-left">
                <img src="/Content/assets/images/delivery-center/map-pin.png" />
                <p class="black-color"> 474, 15- B Cross <Br> Yelahanka New Town- Bangalore,- 560064</p>
            </div>
            <div class="more-detail-contact">
                <p><b class="fw-500">Mobile Number -</b>  <span class="fw-400">9980754550</span></p>
            </div>
                <a href="javascript:getMapDirection(13.10255, 77.57672,'Shiva Divine Enterprises');" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=13.10255,77.57672" target="_blank" class="getdirectin"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=13.10255,77.57672" target="_self" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <span class="lat d-none">13.10255</span>
                <span class="lng d-none">77.57672</span>
            <a class="puc-store">Wonder World Quick</a>
        </div>
        <div class="contact-boxright mbottom delivery-rightgreybox">
            <h5 class="right-titlebox">Mahaveer Nutrition </h5>
            <div class="icon-with-left">
                <img src="/Content/assets/images/delivery-center/map-pin.png" />
                <p class="black-color"> No.177/1, Shop No.2, B T Street,  Avenue Road Cross <Br> Anchepet- Bangalore ,- 560053</p>
            </div>
            <div class="more-detail-contact">
                <p><b class="fw-500">Mobile Number -</b>  <span class="fw-400">9844364477</span></p>
            </div>
                <a href="javascript:getMapDirection(12.97140, 77.58025,'Mahaveer Nutrition ');" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=12.97140,77.58025" target="_blank" class="getdirectin"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=12.97140,77.58025" target="_self" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <span class="lat d-none">12.97140</span>
                <span class="lng d-none">77.58025</span>
            <a class="puc-store">Puc</a>
        </div>
        <div class="contact-boxright mbottom delivery-rightgreybox">
            <h5 class="right-titlebox">K K Enterprises </h5>
            <div class="icon-with-left">
                <img src="/Content/assets/images/delivery-center/map-pin.png" />
                <p class="black-color"> No.19, Chamundeswari Layout <Br> Bangalore- Vidyaranyapura,- 560097</p>
            </div>
            <div class="more-detail-contact">
                <p><b class="fw-500">Mobile Number -</b>  <span class="fw-400">9036195666</span></p>
            </div>
                <a href="javascript:getMapDirection(13.06277, 77.55477,'K K Enterprises ');" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=13.06277,77.55477" target="_blank" class="getdirectin"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=13.06277,77.55477" target="_self" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <span class="lat d-none">13.06277</span>
                <span class="lng d-none">77.55477</span>
            <a class="puc-store">Puc</a>
        </div>
        <div class="contact-boxright mbottom delivery-rightgreybox">
            <h5 class="right-titlebox">Mona Enterprises</h5>
            <div class="icon-with-left">
                <img src="/Content/assets/images/delivery-center/map-pin.png" />
                <p class="black-color"> 2, 2nd Stage, Karnataka Layout, Next To St. Mary School, Basaveshwaranagar <Br> Bangalore- Basaveshwaranagar,- 560079</p>
            </div>
            <div class="more-detail-contact">
                <p><b class="fw-500">Mobile Number -</b>  <span class="fw-400">9036632112</span></p>
            </div>
                <a href="javascript:getMapDirection(13, 78,'Mona Enterprises');" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=13,78" target="_blank" class="getdirectin"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=13,78" target="_self" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <span class="lat d-none">13</span>
                <span class="lng d-none">78</span>
            <a class="puc-store">Keysoul Outlet</a>
        </div>
        <div class="contact-boxright mbottom delivery-rightgreybox">
            <h5 class="right-titlebox">Malige Mithra Vision Key Soul Center</h5>
            <div class="icon-with-left">
                <img src="/Content/assets/images/delivery-center/map-pin.png" />
                <p class="black-color"> #- 233, Samrudhi, 8th Main, 4th Cross, 2nd Block, Nandini Lyaout <Br> Bangalore,- 560096</p>
            </div>
            <div class="more-detail-contact">
                <p><b class="fw-500">Mobile Number -</b>  <span class="fw-400">9980260946</span></p>
            </div>
                <a href="javascript:getMapDirection(25, 75,'Malige Mithra Vision Key Soul Center');" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=25,75" target="_blank" class="getdirectin"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=25,75" target="_self" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <span class="lat d-none">25</span>
                <span class="lng d-none">75</span>
            <a class="puc-store">Keysoul Outlet</a>
        </div>
        <div class="contact-boxright mbottom delivery-rightgreybox">
            <h5 class="right-titlebox">Diamonds House</h5>
            <div class="icon-with-left">
                <img src="/Content/assets/images/delivery-center/map-pin.png" />
                <p class="black-color"> No.1269, 1st Floor, Kempegowda Layout, Near Narayana E Techno School, Near Kempegowda Arch Bus Stop, Service Road <Br> Bangalore- Laggere,- 560058</p>
            </div>
            <div class="more-detail-contact">
                <p><b class="fw-500">Mobile Number -</b>  <span class="fw-400">9036632112</span></p>
            </div>
                <a href="javascript:getMapDirection(12.99886, 77.52637,'Diamonds House');" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=12.99886,77.52637" target="_blank" class="getdirectin"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=12.99886,77.52637" target="_self" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <span class="lat d-none">12.99886</span>
                <span class="lng d-none">77.52637</span>
            <a class="puc-store">Wonder World Quick</a>
        </div>
        <div class="contact-boxright mbottom delivery-rightgreybox">
            <h5 class="right-titlebox">Ifs Business Private Limited</h5>
            <div class="icon-with-left">
                <img src="/Content/assets/images/delivery-center/map-pin.png" />
                <p class="black-color"> . <Br> Whitefield- Nagondanahalli,- 560066</p>
            </div>
            <div class="more-detail-contact">
                <p><b class="fw-500">Mobile Number -</b>  <span class="fw-400">9439551661</span></p>
            </div>
                <a href="javascript:getMapDirection(12.97134, 77.76263,'Ifs Business Private Limited');" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=12.97134,77.76263" target="_blank" class="getdirectin"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=12.97134,77.76263" target="_self" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <span class="lat d-none">12.97134</span>
                <span class="lng d-none">77.76263</span>
            <a class="puc-store">Wonder World Quick</a>
        </div>
        <div class="contact-boxright mbottom delivery-rightgreybox">
            <h5 class="right-titlebox">Sri Sai Baba Grp Enterprises</h5>
            <div class="icon-with-left">
                <img src="/Content/assets/images/delivery-center/map-pin.png" />
                <p class="black-color"> No.20, R. K. Mutt Road <Br> Bangalore- Ulsoor,- 560008</p>
            </div>
            <div class="more-detail-contact">
                <p><b class="fw-500">Mobile Number -</b>  <span class="fw-400">9341718974</span></p>
            </div>
                <a href="javascript:getMapDirection(12.98031, 77.62877,'Sri Sai Baba Grp Enterprises');" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=12.98031,77.62877" target="_blank" class="getdirectin"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=12.98031,77.62877" target="_self" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <span class="lat d-none">12.98031</span>
                <span class="lng d-none">77.62877</span>
            <a class="puc-store">Puc</a>
        </div>
        <div class="contact-boxright mbottom delivery-rightgreybox">
            <h5 class="right-titlebox">Malige Mithra Rcm Puc</h5>
            <div class="icon-with-left">
                <img src="/Content/assets/images/delivery-center/map-pin.png" />
                <p class="black-color"> # 11, 1sr Cross, Balaji Layout  <Br> Bangalore,- 560091</p>
            </div>
            <div class="more-detail-contact">
                <p><b class="fw-500">Mobile Number -</b>  <span class="fw-400">9880900084</span></p>
            </div>
                <a href="javascript:getMapDirection(12.98452678241994, 77.47991526016509,'Malige Mithra Rcm Puc');" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=12.98452678241994,77.47991526016509" target="_blank" class="getdirectin"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=12.98452678241994,77.47991526016509" target="_self" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <span class="lat d-none">12.98452678241994</span>
                <span class="lng d-none">77.47991526016509</span>
            <a class="puc-store">Puc</a>
        </div>
        <div class="contact-boxright mbottom delivery-rightgreybox">
            <h5 class="right-titlebox">J.s.s. Rcm Puc</h5>
            <div class="icon-with-left">
                <img src="/Content/assets/images/delivery-center/map-pin.png" />
                <p class="black-color"> #-2, 90/1, 4th Main, Near Janny Backry, Doddanagmangala <Br> Bangalore,- 560100</p>
            </div>
            <div class="more-detail-contact">
                <p><b class="fw-500">Mobile Number -</b>  <span class="fw-400">9343704027</span></p>
            </div>
                <a href="javascript:getMapDirection(12.859540655418, 77.6744153218119,'J.s.s. Rcm Puc');" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=12.859540655418,77.6744153218119" target="_blank" class="getdirectin"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=12.859540655418,77.6744153218119" target="_self" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <span class="lat d-none">12.859540655418</span>
                <span class="lng d-none">77.6744153218119</span>
            <a class="puc-store">Puc</a>
        </div>
        <div class="contact-boxright mbottom delivery-rightgreybox">
            <h5 class="right-titlebox">SAHA HEALTH AND HERBAL LLP</h5>
            <div class="icon-with-left">
                <img src="/Content/assets/images/delivery-center/map-pin.png" />
                <p class="black-color"> Kalasipalya Main Road <Br> Kalasipalya,- 560002</p>
            </div>
            <div class="more-detail-contact">
                <p><b class="fw-500">Mobile Number -</b>  <span class="fw-400">9845452891</span></p>
            </div>
                <a href="javascript:getMapDirection(12.9589517697833, 77.5815385919702,'SAHA HEALTH AND HERBAL LLP');" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=12.9589517697833,77.5815385919702" target="_blank" class="getdirectin"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=12.9589517697833,77.5815385919702" target="_self" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <span class="lat d-none">12.9589517697833</span>
                <span class="lng d-none">77.5815385919702</span>
            <a class="puc-store">Wonder World Quick</a>
        </div>
        <div class="contact-boxright mbottom delivery-rightgreybox">
            <h5 class="right-titlebox">CHIKKAS ORGANICS</h5>
            <div class="icon-with-left">
                <img src="/Content/assets/images/delivery-center/map-pin.png" />
                <p class="black-color"> 50/1/448, 4th Block, Hbr Layout <Br> Bangalore,- 560043</p>
            </div>
            <div class="more-detail-contact">
                <p><b class="fw-500">Mobile Number -</b>  <span class="fw-400">9916946682</span></p>
            </div>
                <a href="javascript:getMapDirection(13.0307925, 77.6333562,'CHIKKAS ORGANICS');" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=13.0307925,77.6333562" target="_blank" class="getdirectin"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=13.0307925,77.6333562" target="_self" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <span class="lat d-none">13.0307925</span>
                <span class="lng d-none">77.6333562</span>
            <a class="puc-store">Wonder World Quick</a>
        </div>
        <div class="contact-boxright mbottom delivery-rightgreybox">
            <h5 class="right-titlebox">V K Swadeshi Mart</h5>
            <div class="icon-with-left">
                <img src="/Content/assets/images/delivery-center/map-pin.png" />
                <p class="black-color"> Hmt Layout, Anandanagar <Br> Bangalore,- 560024</p>
            </div>
            <div class="more-detail-contact">
                <p><b class="fw-500">Mobile Number -</b>  <span class="fw-400">9740019100</span></p>
            </div>
                <a href="javascript:getMapDirection(13.0278875848611, 77.5916411737648,'V K Swadeshi Mart');" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=13.0278875848611,77.5916411737648" target="_blank" class="getdirectin"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=13.0278875848611,77.5916411737648" target="_self" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <span class="lat d-none">13.0278875848611</span>
                <span class="lng d-none">77.5916411737648</span>
            <a class="puc-store">Puc</a>
        </div>
        <div class="contact-boxright mbottom delivery-rightgreybox">
            <h5 class="right-titlebox">Kanya Keysoul Outlet</h5>
            <div class="icon-with-left">
                <img src="/Content/assets/images/delivery-center/map-pin.png" />
                <p class="black-color"> 246, 2nd Main, 3rd Cross, Ngef Layout, Mallathahalli, Near Play Ground <Br> Bengaluru,- 560056</p>
            </div>
            <div class="more-detail-contact">
                <p><b class="fw-500">Mobile Number -</b>  <span class="fw-400">9740787505</span></p>
            </div>
                <a href="javascript:getMapDirection(12.960565964196821, 77.4972084734442,'Kanya Keysoul Outlet');" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=12.960565964196821,77.4972084734442" target="_blank" class="getdirectin"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=12.960565964196821,77.4972084734442" target="_self" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <span class="lat d-none">12.960565964196821</span>
                <span class="lng d-none">77.4972084734442</span>
            <a class="puc-store">Keysoul Outlet</a>
        </div>
        <div class="contact-boxright mbottom delivery-rightgreybox">
            <h5 class="right-titlebox">Bhoomi Organic</h5>
            <div class="icon-with-left">
                <img src="/Content/assets/images/delivery-center/map-pin.png" />
                <p class="black-color"> Shop No.8, Ground Floor, 1st Main Road, Anjaneya Nagaraa, Bsk Lll Stage <Br> Bangalore ,- 560085</p>
            </div>
            <div class="more-detail-contact">
                <p><b class="fw-500">Mobile Number -</b>  <span class="fw-400">8880005018</span></p>
            </div>
                <a href="javascript:getMapDirection(12.928746663946516, 77.54579544067383,'Bhoomi Organic');" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=12.928746663946516,77.54579544067383" target="_blank" class="getdirectin"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=12.928746663946516,77.54579544067383" target="_self" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <span class="lat d-none">12.928746663946516</span>
                <span class="lng d-none">77.54579544067383</span>
            <a class="puc-store">Wonder World Quick</a>
        </div>
        <div class="contact-boxright mbottom delivery-rightgreybox">
            <h5 class="right-titlebox">Brik Mart India Pvt Ltd</h5>
            <div class="icon-with-left">
                <img src="/Content/assets/images/delivery-center/map-pin.png" />
                <p class="black-color"> Infra House, No 456/11/1, Hennur Bagalur Road <Br> Bangalore- Henuur,- 560043</p>
            </div>
            <div class="more-detail-contact">
                <p><b class="fw-500">Mobile Number -</b>  <span class="fw-400">9845889989</span></p>
            </div>
                <a href="javascript:getMapDirection(13.0387076785491, 77.6416362655517,'Brik Mart India Pvt Ltd');" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=13.0387076785491,77.6416362655517" target="_blank" class="getdirectin"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=13.0387076785491,77.6416362655517" target="_self" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <span class="lat d-none">13.0387076785491</span>
                <span class="lng d-none">77.6416362655517</span>
            <a class="puc-store">Tulsi Paint</a>
        </div>
        <div class="contact-boxright mbottom delivery-rightgreybox">
            <h5 class="right-titlebox">Nirmal Rcm Bazaar</h5>
            <div class="icon-with-left">
                <img src="/Content/assets/images/delivery-center/map-pin.png" />
                <p class="black-color"> #273, 1st Main, 2nd Cross, Rajagopala Nagar, Peenya 2nd Stage <Br> Bangalore,- 560058</p>
            </div>
            <div class="more-detail-contact">
                <p><b class="fw-500">Mobile Number -</b>  <span class="fw-400">8088736332</span></p>
            </div>
                <a href="javascript:getMapDirection(13.0175969, 77.5135728,'Nirmal Rcm Bazaar');" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=13.0175969,77.5135728" target="_blank" class="getdirectin"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=13.0175969,77.5135728" target="_self" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <span class="lat d-none">13.0175969</span>
                <span class="lng d-none">77.5135728</span>
            <a class="puc-store">Wonder World Quick</a>
        </div>
        <div class="contact-boxright mbottom delivery-rightgreybox">
            <h5 class="right-titlebox">Pragathi Rcm Kso</h5>
            <div class="icon-with-left">
                <img src="/Content/assets/images/delivery-center/map-pin.png" />
                <p class="black-color"> No 37, 1st Main, 2nd Cross, Shivananda Nagar, Hegganahalli <Br> Bengaluru,- 560091</p>
            </div>
            <div class="more-detail-contact">
                <p><b class="fw-500">Mobile Number -</b>  <span class="fw-400">9844434199</span></p>
            </div>
                <a href="javascript:getMapDirection(12.9715987, 77.5945627,'Pragathi Rcm Kso');" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=12.9715987,77.5945627" target="_blank" class="getdirectin"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=12.9715987,77.5945627" target="_self" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <span class="lat d-none">12.9715987</span>
                <span class="lng d-none">77.5945627</span>
            <a class="puc-store">Keysoul Outlet</a>
        </div>
        <div class="contact-boxright mbottom delivery-rightgreybox">
            <h5 class="right-titlebox">WONDER WORLD BANGALORE</h5>
            <div class="icon-with-left">
                <img src="/Content/assets/images/delivery-center/map-pin.png" />
                <p class="black-color"> BLK NO.103/1, 36TH CROSS,2ND MAIN ROAD, 2ND BLOCK, RAJAJINAGAR, BBMP WARD NO.99,
OPP.TVS SHOWROOM,DR.RAJKUMAR ROAD <Br> BANGALORE- RAJAJINAGAR,- 560010</p>
            </div>
            <div class="more-detail-contact">
                <p><b class="fw-500">Mobile Number -</b>  <span class="fw-400">9342101471</span></p>
            </div>
            <a class="puc-store">Bazaar</a>
        </div>
        <div class="contact-boxright mbottom delivery-rightgreybox">
            <h5 class="right-titlebox">Bengaluru</h5>
            <div class="icon-with-left">
                <img src="/Content/assets/images/delivery-center/map-pin.png" />
                <p class="black-color"> Plot No.111/d, Bammsandra Industrial Area Behind S.k.f. Factory
 <Br> Bengaluru,- 560099</p>
            </div>
            <div class="more-detail-contact">
                <p><b class="fw-500">Mobile Number -</b>  <span class="fw-400">9341856378</span></p>
            </div>
                <a href="javascript:getMapDirection(13.0612623854504, 77.7420419454575,'Bengaluru');" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=13.0612623854504,77.7420419454575" target="_blank" class="getdirectin"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=13.0612623854504,77.7420419454575" target="_self" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <span class="lat d-none">13.0612623854504</span>
                <span class="lng d-none">77.7420419454575</span>
            <a class="puc-store">Depot</a>
        </div>
        <div class="contact-boxright mbottom delivery-rightgreybox">
            <h5 class="right-titlebox">Bengaluru Tulsi Paint</h5>
            <div class="icon-with-left">
                <img src="/Content/assets/images/delivery-center/map-pin.png" />
                <p class="black-color"> Ahshwini Nilaya,3rd Main,4th Block,kalyana Nagar Bda Complex,kalyannagar,bangalore
 <Br> Bengaluru,- 560043</p>
            </div>
            <div class="more-detail-contact">
                <p><b class="fw-500">Mobile Number -</b>  <span class="fw-400">9916946682</span></p>
            </div>
            <a class="puc-store">Depot</a>
        </div>

# %%
        <div class="contact-boxright mbottom delivery-rightgreybox">
            <h5 class="right-titlebox">Sri Annapurneshwari Health Bazar</h5>
            <div class="icon-with-left">
                <img src="/Content/assets/images/delivery-center/map-pin.png" />
                <p class="black-color"> #-60, 5th Ward, Air Badavane, Police Quatters <Br> Hosakote,- 562114</p>
            </div>
            <div class="more-detail-contact">
                <p><b class="fw-500">Mobile Number -</b>  <span class="fw-400">9980497654</span></p>
            </div>
                <a href="javascript:getMapDirection(13.07300, 77.79670,'Sri Annapurneshwari Health Bazar');" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=13.07300,77.79670" target="_blank" class="getdirectin"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=13.07300,77.79670" target="_self" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <span class="lat d-none">13.07300</span>
                <span class="lng d-none">77.79670</span>
            <a class="puc-store">Puc</a>
        </div>
        <div class="contact-boxright mbottom delivery-rightgreybox">
            <h5 class="right-titlebox">Shree Lakshmi NarasimhaSwamy rcm puc</h5>
            <div class="icon-with-left">
                <img src="/Content/assets/images/delivery-center/map-pin.png" />
                <p class="black-color"> Siddi Vinayaka Main Road, Near Sangeetha Complex, Gangadharapura <Br> Doddaballapur- Gangadharapura,- 561203</p>
            </div>
            <div class="more-detail-contact">
                <p><b class="fw-500">Mobile Number -</b>  <span class="fw-400">7019270082</span></p>
            </div>
                <a href="javascript:getMapDirection(13.30715, 77.51751,'Shree Lakshmi NarasimhaSwamy rcm puc');" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=13.30715,77.51751" target="_blank" class="getdirectin"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=13.30715,77.51751" target="_self" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <span class="lat d-none">13.30715</span>
                <span class="lng d-none">77.51751</span>
            <a class="puc-store">Puc</a>
        </div>
        <div class="contact-boxright mbottom delivery-rightgreybox">
            <h5 class="right-titlebox">Shiva Rcm Store</h5>
            <div class="icon-with-left">
                <img src="/Content/assets/images/delivery-center/map-pin.png" />
                <p class="black-color"> . <Br> Arasanahalli,- 562129</p>
            </div>
            <div class="more-detail-contact">
                <p><b class="fw-500">Mobile Number -</b>  <span class="fw-400">9980824913</span></p>
            </div>
            <a class="puc-store">Wonder World Quick</a>
        </div>
        <div class="contact-boxright mbottom delivery-rightgreybox">
            <h5 class="right-titlebox">Maruthi Rcm Bazar </h5>
            <div class="icon-with-left">
                <img src="/Content/assets/images/delivery-center/map-pin.png" />
                <p class="black-color"> Thymagondalu Road  <Br> Kalalugatta ,- 562132</p>
            </div>
            <div class="more-detail-contact">
                <p><b class="fw-500">Mobile Number -</b>  <span class="fw-400">9880635892</span></p>
            </div>
                <a href="javascript:getMapDirection(25, 75,'Maruthi Rcm Bazar ');" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=25,75" target="_blank" class="getdirectin"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=25,75" target="_self" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <span class="lat d-none">25</span>
                <span class="lng d-none">75</span>
            <a class="puc-store">Puc</a>
        </div>
        <div class="contact-boxright mbottom delivery-rightgreybox">
            <h5 class="right-titlebox">Nisarga Natural And Organic Bazar</h5>
            <div class="icon-with-left">
                <img src="/Content/assets/images/delivery-center/map-pin.png" />
                <p class="black-color"> Maruthi Complex, Post Office Road, Behind Ksrtcbus Stand, Indiranagara <Br> Nelamangala,- 562123</p>
            </div>
            <div class="more-detail-contact">
                <p><b class="fw-500">Mobile Number -</b>  <span class="fw-400">9632750027</span></p>
            </div>
                <a href="javascript:getMapDirection(13.0905114716053, 77.3883332255402,'Nisarga Natural And Organic Bazar');" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=13.0905114716053,77.3883332255402" target="_blank" class="getdirectin"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=13.0905114716053,77.3883332255402" target="_self" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <span class="lat d-none">13.0905114716053</span>
                <span class="lng d-none">77.3883332255402</span>
            <a class="puc-store">Puc</a>
        </div>
        <div class="contact-boxright mbottom delivery-rightgreybox">
            <h5 class="right-titlebox">Sri Sai Rcm Mart</h5>
            <div class="icon-with-left">
                <img src="/Content/assets/images/delivery-center/map-pin.png" />
                <p class="black-color"> Mandibelle Road <Br> Vijayapura,- 562135</p>
            </div>
            <div class="more-detail-contact">
                <p><b class="fw-500">Mobile Number -</b>  <span class="fw-400">9141698248</span></p>
            </div>
                <a href="javascript:getMapDirection(13.2971102192049, 77.7987922027371,'Sri Sai Rcm Mart');" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=13.2971102192049,77.7987922027371" target="_blank" class="getdirectin"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=13.2971102192049,77.7987922027371" target="_self" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <span class="lat d-none">13.2971102192049</span>
                <span class="lng d-none">77.7987922027371</span>
            <a class="puc-store">Wonder World Quick</a>
        </div>
        <div class="contact-boxright mbottom delivery-rightgreybox">
            <h5 class="right-titlebox">Hanvita Organic Products</h5>
            <div class="icon-with-left">
                <img src="/Content/assets/images/delivery-center/map-pin.png" />
                <p class="black-color"> Shubash Nagar, Near Rmc Market <Br> Doddaballapur,- 561203</p>
            </div>
            <div class="more-detail-contact">
                <p><b class="fw-500">Mobile Number -</b>  <span class="fw-400">9060557775</span></p>
            </div>
                <a href="javascript:getMapDirection(13.31129313744497, 77.53741482762197,'Hanvita Organic Products');" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=13.31129313744497,77.53741482762197" target="_blank" class="getdirectin"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=13.31129313744497,77.53741482762197" target="_self" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <span class="lat d-none">13.31129313744497</span>
                <span class="lng d-none">77.53741482762197</span>
            <a class="puc-store">Tulsi Paint</a>
        </div>
        <div class="contact-boxright mbottom delivery-rightgreybox">
            <h5 class="right-titlebox">Arunodaya Enterprises</h5>
            <div class="icon-with-left">
                <img src="/Content/assets/images/delivery-center/map-pin.png" />
                <p class="black-color"> Subbamma Channappa Samudaya Bavana <Br> Vijayapura,- 562135</p>
            </div>
            <div class="more-detail-contact">
                <p><b class="fw-500">Mobile Number -</b>  <span class="fw-400">9886998552</span></p>
            </div>
                <a href="javascript:getMapDirection(13.2968249604018, 77.8005025449829,'Arunodaya Enterprises');" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=13.2968249604018,77.8005025449829" target="_blank" class="getdirectin"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=13.2968249604018,77.8005025449829" target="_self" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <span class="lat d-none">13.2968249604018</span>
                <span class="lng d-none">77.8005025449829</span>
            <a class="puc-store">Tulsi Paint</a>
        </div>
        <div class="contact-boxright mbottom delivery-rightgreybox">
            <h5 class="right-titlebox">S L N Traders</h5>
            <div class="icon-with-left">
                <img src="/Content/assets/images/delivery-center/map-pin.png" />
                <p class="black-color"> Near Subbama Chanappa Chotry <Br> Vijayapura ,- 562135</p>
            </div>
            <div class="more-detail-contact">
                <p><b class="fw-500">Mobile Number -</b>  <span class="fw-400">9964764217</span></p>
            </div>
                <a href="javascript:getMapDirection(13.2969131112354, 77.7985865594699,'S L N Traders');" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=13.2969131112354,77.7985865594699" target="_blank" class="getdirectin"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=13.2969131112354,77.7985865594699" target="_self" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <span class="lat d-none">13.2969131112354</span>
                <span class="lng d-none">77.7985865594699</span>
            <a class="puc-store">Wonder World Quick</a>
        </div>

# %%
        <div class="contact-boxright mbottom delivery-rightgreybox">
            <h5 class="right-titlebox">Pavitra Rcm Indian Family Mart</h5>
            <div class="icon-with-left">
                <img src="/Content/assets/images/delivery-center/map-pin.png" />
                <p class="black-color"> 17/197, Tilak Nagar, Old Gooty Road <Br> Guntakal,- 515801</p>
            </div>
            <div class="more-detail-contact">
                <p><b class="fw-500">Mobile Number -</b>  <span class="fw-400">8639497628</span></p>
            </div>
                <a href="javascript:getMapDirection(15.16226, 77.38268,'Pavitra Rcm Indian Family Mart');" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=15.16226,77.38268" target="_blank" class="getdirectin"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=15.16226,77.38268" target="_self" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <span class="lat d-none">15.16226</span>
                <span class="lng d-none">77.38268</span>
            <a class="puc-store">Puc</a>
        </div>
        <div class="contact-boxright mbottom delivery-rightgreybox">
            <h5 class="right-titlebox">Chandrahasa Rcm Family Mart</h5>
            <div class="icon-with-left">
                <img src="/Content/assets/images/delivery-center/map-pin.png" />
                <p class="black-color"> 1/126, Flot- 44, Bnr Colony <Br> Rachanapalli,- 515004</p>
            </div>
            <div class="more-detail-contact">
                <p><b class="fw-500">Mobile Number -</b>  <span class="fw-400">9966925523</span></p>
            </div>
                <a href="javascript:getMapDirection(14.6991572, 77.5332796,'Chandrahasa Rcm Family Mart');" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=14.6991572,77.5332796" target="_blank" class="getdirectin"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=14.6991572,77.5332796" target="_self" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <span class="lat d-none">14.6991572</span>
                <span class="lng d-none">77.5332796</span>
            <a class="puc-store">Wonder World Quick</a>
        </div>
        <div class="contact-boxright mbottom delivery-rightgreybox">
            <h5 class="right-titlebox">Hanuman Traders</h5>
            <div class="icon-with-left">
                <img src="/Content/assets/images/delivery-center/map-pin.png" />
                <p class="black-color"> No 26-8-1322/1-4, <Br> Melapur,- 515201</p>
            </div>
            <div class="more-detail-contact">
                <p><b class="fw-500">Mobile Number -</b>  <span class="fw-400">8121825808</span></p>
            </div>
                <a href="javascript:getMapDirection(13.838518699023359, 77.50138864178476,'Hanuman Traders');" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=13.838518699023359,77.50138864178476" target="_blank" class="getdirectin"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=13.838518699023359,77.50138864178476" target="_self" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <span class="lat d-none">13.838518699023359</span>
                <span class="lng d-none">77.50138864178476</span>
            <a class="puc-store">Tulsi Paint</a>
        </div>

# %%
        <div class="contact-boxright mbottom delivery-rightgreybox">
            <h5 class="right-titlebox">Yogaaamrutha Rcm Store</h5>
            <div class="icon-with-left">
                <img src="/Content/assets/images/delivery-center/map-pin.png" />
                <p class="black-color"> Door No.4-45- B, 14th Cross, Sree Krishna Nagar, Opp Srikrishna Mandir,     M. R. Palli <Br> Tirupati,- 517504</p>
            </div>
            <div class="more-detail-contact">
                <p><b class="fw-500">Mobile Number -</b>  <span class="fw-400">9440643668</span></p>
            </div>
                <a href="javascript:getMapDirection(13.61576, 79.40712,'Yogaaamrutha Rcm Store');" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=13.61576,79.40712" target="_blank" class="getdirectin"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <a href="https://www.google.com/maps/search/?api=1&amp;query=13.61576,79.40712" target="_self" class="getdirectin d-none"><img src="/Content/assets/images/delivery-center/map-colorpin.png"> Get Direction</a>
                <span class="lat d-none">13.61576</span>
                <span class="lng d-none">79.40712</span>
            <a class="puc-store">Puc</a>
        </div>

# %%
[
    {"data":{"view":"\r\n\r\n        <div class=\"contact-boxright mbottom delivery-rightgreybox\">\r\n            <h5 class=\"right-titlebox\">Only Rcm Pick Up Center</h5>\r\n            <div class=\"icon-with-left\">\r\n                <img src=\"/Content/assets/images/delivery-center/map-pin.png\" />\r\n                <p class=\"black-color\"> 5/77, Ramula Street <Br> Kotthamadhavara,- 516247</p>\r\n            </div>\r\n            <div class=\"more-detail-contact\">\r\n                <p><b class=\"fw-500\">Mobile Number -</b>  <span class=\"fw-400\">9290308513</span></p>\r\n            </div>\r\n                <a href=\"javascript:getMapDirection(14.4109, 78.9950,'Only Rcm Pick Up Center');\" class=\"getdirectin d-none\"><img src=\"/Content/assets/images/delivery-center/map-colorpin.png\"> Get Direction</a>\r\n                <a href=\"https://www.google.com/maps/search/?api=1&amp;query=14.4109,78.9950\" target=\"_blank\" class=\"getdirectin\"><img src=\"/Content/assets/images/delivery-center/map-colorpin.png\"> Get Direction</a>\r\n                <a href=\"https://www.google.com/maps/search/?api=1&amp;query=14.4109,78.9950\" target=\"_self\" class=\"getdirectin d-none\"><img src=\"/Content/assets/images/delivery-center/map-colorpin.png\"> Get Direction</a>\r\n                <span class=\"lat d-none\">14.4109</span>\r\n                <span class=\"lng d-none\">78.9950</span>\r\n            <a class=\"puc-store\">Puc</a>\r\n        </div>\r\n        <div class=\"contact-boxright mbottom delivery-rightgreybox\">\r\n            <h5 class=\"right-titlebox\">Pothuraju Rcm Puc</h5>\r\n            <div class=\"icon-with-left\">\r\n                <img src=\"/Content/assets/images/delivery-center/map-pin.png\" />\r\n                <p class=\"black-color\"> 6/21-a, Gandhi Street, Diguvapeta <Br> Siddhavattam,- 516237</p>\r\n            </div>\r\n            <div class=\"more-detail-contact\">\r\n                <p><b class=\"fw-500\">Mobile Number -</b>  <span class=\"fw-400\">9441822690</span></p>\r\n            </div>\r\n                <a href=\"javascript:getMapDirection(14.4667, 78.9698,'Pothuraju Rcm Puc');\" class=\"getdirectin d-none\"><img src=\"/Content/assets/images/delivery-center/map-colorpin.png\"> Get Direction</a>\r\n                <a href=\"https://www.google.com/maps/search/?api=1&amp;query=14.4667,78.9698\" target=\"_blank\" class=\"getdirectin\"><img src=\"/Content/assets/images/delivery-center/map-colorpin.png\"> Get Direction</a>\r\n                <a href=\"https://www.google.com/maps/search/?api=1&amp;query=14.4667,78.9698\" target=\"_self\" class=\"getdirectin d-none\"><img src=\"/Content/assets/images/delivery-center/map-colorpin.png\"> Get Direction</a>\r\n                <span class=\"lat d-none\">14.4667</span>\r\n                <span class=\"lng d-none\">78.9698</span>\r\n            <a class=\"puc-store\">Puc</a>\r\n        </div>\r\n        <div class=\"contact-boxright mbottom delivery-rightgreybox\">\r\n            <h5 class=\"right-titlebox\">Sameer Rcm Pick Up Center</h5>\r\n            <div class=\"icon-with-left\">\r\n                <img src=\"/Content/assets/images/delivery-center/map-pin.png\" />\r\n                <p class=\"black-color\"> 2/246, Mahaboob Nagar Street <Br> Rajampet,- 516115</p>\r\n            </div>\r\n            <div class=\"more-detail-contact\">\r\n                <p><b class=\"fw-500\">Mobile Number -</b>  <span class=\"fw-400\">7893242117</span></p>\r\n            </div>\r\n                <a href=\"javascript:getMapDirection(14.19183, 79.16469,'Sameer Rcm Pick Up Center');\" class=\"getdirectin d-none\"><img src=\"/Content/assets/images/delivery-center/map-colorpin.png\"> Get Direction</a>\r\n                <a href=\"https://www.google.com/maps/search/?api=1&amp;query=14.19183,79.16469\" target=\"_blank\" class=\"getdirectin\"><img src=\"/Content/assets/images/delivery-center/map-colorpin.png\"> Get Direction</a>\r\n                <a href=\"https://www.google.com/maps/search/?api=1&amp;query=14.19183,79.16469\" target=\"_self\" class=\"getdirectin d-none\"><img src=\"/Content/assets/images/delivery-center/map-colorpin.png\"> Get Direction</a>\r\n                <span class=\"lat d-none\">14.19183</span>\r\n                <span class=\"lng d-none\">79.16469</span>\r\n            <a class=\"puc-store\">Puc</a>\r\n        </div>\r\n        <div class=\"contact-boxright mbottom delivery-rightgreybox\">\r\n            <h5 class=\"right-titlebox\">Sree Venkata Sai Sahasra Rcm Enterprises</h5>\r\n            <div class=\"icon-with-left\">\r\n                <img src=\"/Content/assets/images/delivery-center/map-pin.png\" />\r\n                <p class=\"black-color\"> Room No.20, Kandula Complex, Pulivedula Road <Br> Vempalli,- 516329</p>\r\n            </div>\r\n            <div class=\"more-detail-contact\">\r\n                <p><b class=\"fw-500\">Mobile Number -</b>  <span class=\"fw-400\">9100476818</span></p>\r\n            </div>\r\n                <a href=\"javascript:getMapDirection(14.36615, 78.45856,'Sree Venkata Sai Sahasra Rcm Enterprises');\" class=\"getdirectin d-none\"><img src=\"/Content/assets/images/delivery-center/map-colorpin.png\"> Get Direction</a>\r\n                <a href=\"https://www.google.com/maps/search/?api=1&amp;query=14.36615,78.45856\" target=\"_blank\" class=\"getdirectin\"><img src=\"/Content/assets/images/delivery-center/map-colorpin.png\"> Get Direction</a>\r\n                <a href=\"https://www.google.com/maps/search/?api=1&amp;query=14.36615,78.45856\" target=\"_self\" class=\"getdirectin d-none\"><img src=\"/Content/assets/images/delivery-center/map-colorpin.png\"> Get Direction</a>\r\n                <span class=\"lat d-none\">14.36615</span>\r\n                <span class=\"lng d-none\">78.45856</span>\r\n            <a class=\"puc-store\">Puc</a>\r\n        </div>\r\n        <div class=\"contact-boxright mbottom delivery-rightgreybox\">\r\n            <h5 class=\"right-titlebox\">Satya Sai Balaji Traders</h5>\r\n            <div class=\"icon-with-left\">\r\n                <img src=\"/Content/assets/images/delivery-center/map-pin.png\" />\r\n                <p class=\"black-color\"> 17/558-1, Habibulla Streest, Opp. Andhra Bank <Br> Kadapa,- 516002</p>\r\n            </div>\r\n            <div class=\"more-detail-contact\">\r\n                <p><b class=\"fw-500\">Mobile Number -</b>  <span class=\"fw-400\">8341060446</span></p>\r\n            </div>\r\n                <a href=\"javascript:getMapDirection(14.48291, 78.82376,'Satya Sai Balaji Traders');\" class=\"getdirectin d-none\"><img src=\"/Content/assets/images/delivery-center/map-colorpin.png\"> Get Direction</a>\r\n                <a href=\"https://www.google.com/maps/search/?api=1&amp;query=14.48291,78.82376\" target=\"_blank\" class=\"getdirectin\"><img src=\"/Content/assets/images/delivery-center/map-colorpin.png\"> Get Direction</a>\r\n                <a href=\"https://www.google.com/maps/search/?api=1&amp;query=14.48291,78.82376\" target=\"_self\" class=\"getdirectin d-none\"><img src=\"/Content/assets/images/delivery-center/map-colorpin.png\"> Get Direction</a>\r\n                <span class=\"lat d-none\">14.48291</span>\r\n                <span class=\"lng d-none\">78.82376</span>\r\n            <a class=\"puc-store\">Puc</a>\r\n        </div>\r\n        <div class=\"contact-boxright mbottom delivery-rightgreybox\">\r\n            <h5 class=\"right-titlebox\">Mana Swadeshi Rcm Stores </h5>\r\n            <div class=\"icon-with-left\">\r\n                <img src=\"/Content/assets/images/delivery-center/map-pin.png\" />\r\n                <p class=\"black-color\"> D/no.4143/2- A, Opp Subbarao Hotel, Rs Road <Br> Nandalur,- 516150</p>\r\n            </div>\r\n            <div class=\"more-detail-contact\">\r\n                <p><b class=\"fw-500\">Mobile Number -</b>  <span class=\"fw-400\">7799436277</span></p>\r\n            </div>\r\n                <a href=\"javascript:getMapDirection(14.26784, 79.10504,'Mana Swadeshi Rcm Stores ');\" class=\"getdirectin d-none\"><img src=\"/Content/assets/images/delivery-center/map-colorpin.png\"> Get Direction</a>\r\n                <a href=\"https://www.google.com/maps/search/?api=1&amp;query=14.26784,79.10504\" target=\"_blank\" class=\"getdirectin\"><img src=\"/Content/assets/images/delivery-center/map-colorpin.png\"> Get Direction</a>\r\n                <a href=\"https://www.google.com/maps/search/?api=1&amp;query=14.26784,79.10504\" target=\"_self\" class=\"getdirectin d-none\"><img src=\"/Content/assets/images/delivery-center/map-colorpin.png\"> Get Direction</a>\r\n                <span class=\"lat d-none\">14.26784</span>\r\n                <span class=\"lng d-none\">79.10504</span>\r\n            <a class=\"puc-store\">Puc</a>\r\n        </div>\r\n        <div class=\"contact-boxright mbottom delivery-rightgreybox\">\r\n            <h5 class=\"right-titlebox\">Kadapa</h5>\r\n            <div class=\"icon-with-left\">\r\n                <img src=\"/Content/assets/images/delivery-center/map-pin.png\" />\r\n                <p class=\"black-color\"> 42-138-5-2, N.g.o Colony, Revenue Ward 42, City-kadapa, Dist.-kadapa (andhra Pradesh )-516002.\n <Br> Kadapa,- 516002</p>\r\n            </div>\r\n            <div class=\"more-detail-contact\">\r\n                <p><b class=\"fw-500\">Mobile Number -</b>  <span class=\"fw-400\">8885392799</span></p>\r\n            </div>\r\n                <a href=\"javascript:getMapDirection(14.4665549208127, 78.8449287414551,'Kadapa');\" class=\"getdirectin d-none\"><img src=\"/Content/assets/images/delivery-center/map-colorpin.png\"> Get Direction</a>\r\n                <a href=\"https://www.google.com/maps/search/?api=1&amp;query=14.4665549208127,78.8449287414551\" target=\"_blank\" class=\"getdirectin\"><img src=\"/Content/assets/images/delivery-center/map-colorpin.png\"> Get Direction</a>\r\n                <a href=\"https://www.google.com/maps/search/?api=1&amp;query=14.4665549208127,78.8449287414551\" target=\"_self\" class=\"getdirectin d-none\"><img src=\"/Content/assets/images/delivery-center/map-colorpin.png\"> Get Direction</a>\r\n                <span class=\"lat d-none\">14.4665549208127</span>\r\n                <span class=\"lng d-none\">78.8449287414551</span>\r\n            <a class=\"puc-store\">Depot</a>\r\n        </div>\r\n","close":false},"redirectUrl":null,"isSuccess":true,"alertMessage":null}
]
