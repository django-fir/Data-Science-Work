# %%
# !gdown 1s2TkjSpzNc4SyxqRrQleZyDIHlc7bxnd
# !gdown 1Ws-_s1fHZ9nHfGLVUQurbHDvStePlEJm
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1s2TkjSpzNc4SyxqRrQleZyDIHlc7bxnd
# To: /content/movies.csv
# 100% 112k/112k [00:00<00:00, 85.9MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1Ws-_s1fHZ9nHfGLVUQurbHDvStePlEJm
# To: /content/directors.csv
# 100% 65.4k/65.4k [00:00<00:00, 103MB/s]

# %%
# !gdown 1UViHcT4lKDsTfc97gBqIvds25uHe4b5e
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1UViHcT4lKDsTfc97gBqIvds25uHe4b5e
# To: /content/sales.csv
# 100% 94.9M/94.9M [00:02<00:00, 41.4MB/s]

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('sales.csv')
df.head()
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#            InvoiceDate  Price  Customer ID         Country
# 0  2009-12-01 07:45:00   6.95      13085.0  United Kingdom
# 1  2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 2  2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 3  2009-12-01 07:45:00   2.10      13085.0  United Kingdom
# 4  2009-12-01 07:45:00   1.25      13085.0  United Kingdom

# %%
data = {
    'Name': ['Himanshu', 'Robert', 'Karie', 'Rohan', 'John'],
    'Age': [15, 14, 15, 16, 17],
    'Percentage': [80, 77, 83, 45, 70],
    'Stream': ['Commerce', 'Science', 'Arts', 'Commerce', 'Science']
}

df = pd.DataFrame(data)

# %%
df_new=df[df['Percentage']>=75]

# %%
df_new[df_new['Stream'].isin(['Commerce','Arts'])]['Name']
# Out:
# 0    Himanshu
# 2       Karie
# Name: Name, dtype: object

# %%
def get_roll(x):
        return x[x['marks'].max()==x['marks']]

# %%
df.groupby('Country')['Price'].agg('mean').reset_index().set_index('Country')
# Out:
#                           Price
# Country
# Australia              4.239974
# Austria                4.460896
# Bahrain                3.488016
# Belgium                4.728428
# Bermuda                2.491176
# Brazil                 2.726702
# Canada                 4.640746
# Channel Islands        5.442788
# Cyprus                 5.386012
# Czech Republic         2.938333
# Denmark                2.934994
# EIRE                   7.013626
# European Community     4.820492
# Finland                4.990095
# France                 4.691648
# Germany                3.833662
# Greece                 3.922670
# Hong Kong             57.573846
# Iceland                2.546087
# Israel                 3.567305
# Italy                  5.527679
# Japan                  2.162560
# Korea                  2.384762
# Lebanon                6.182931
# Lithuania              2.615926
# Malta                 21.991940
# Netherlands            3.047321
# Nigeria                3.415000
# ...

# %%
df['total'] = df['Quantity']*df['Price']

# %%
df.groupby('Invoice')['total'].sum().sort_values(ascending=False)
# Out:
# Invoice
# 581483     168469.60
# 541431      77183.60
# 574941      52940.94
# 576365      50653.91
# 533027      49844.99
#              ...
# C556445    -38970.00
# A516228    -44031.79
# A506401    -53594.36
# C541433    -77183.60
# C581484   -168469.60
# Name: total, Length: 53628, dtype: float64

# %%
df[df['Invoice']=='581483']
# Out:
#         Invoice StockCode                  Description  Quantity  \
# 1065882  581483     23843  PAPER CRAFT , LITTLE BIRDIE     80995
#
#                  InvoiceDate  Price  Customer ID         Country     total
# 1065882  2011-12-09 09:15:00   2.08      16446.0  United Kingdom  168469.6

# %%
df.groupby(['Invoice','Customer ID'])['StockCode'].count()
# Out:
# Invoice  Customer ID
# 489434   13085.0         8
# 489435   13085.0         4
# 489436   13078.0        19
# 489437   15362.0        23
# 489438   18102.0        17
#                         ..
# C581484  16446.0         1
# C581490  14397.0         2
# C581499  15498.0         1
# C581568  15311.0         1
# C581569  17315.0         2
# Name: StockCode, Length: 44876, dtype: int64

# %%
df.groupby('Customer ID')['StockCode'].count()
# Out:
# Customer ID
# 12346.0     48
# 12347.0    253
# 12348.0     51
# 12349.0    180
# 12350.0     17
#           ...
# 18283.0    986
# 18284.0     29
# 18285.0     12
# 18286.0     70
# 18287.0    156
# Name: StockCode, Length: 5942, dtype: int64

# %%
df.groupby('Invoice')['StockCode'].count()

# %%
df[df['Country']=='United Kingdom']['StockCode'].nunique()
# Out:
# 5303

# %%
df.shape
# Out:
# (1067371, 8)

# %%
df.groupby('Description')['Quantity'].count().sort_values(ascending=False)
# Out:
# Description
# WHITE HANGING HEART T-LIGHT HOLDER    5918
# REGENCY CAKESTAND 3 TIER              4412
# JUMBO BAG RED RETROSPOT               3469
# ASSORTED COLOUR BIRD ORNAMENT         2958
# PARTY BUNTING                         2765
#                                       ...
# wedding co returns?                      1
# wet & rotting                            1
# wet and rotting                          1
# wet boxes                                1
# wet cartons                              1
# Name: Quantity, Length: 5698, dtype: int64

# %%
movies = pd.read_csv('movies.csv')
movies.head()
# Out:
#    Unnamed: 0     id     budget  popularity     revenue  \
# 0           0  43597  237000000         150  2787965087
# 1           1  43598  300000000         139   961000000
# 2           2  43599  245000000         107   880674609
# 3           3  43600  250000000         112  1084939099
# 4           5  43602  258000000         115   890871626
#
#                                       title  vote_average  vote_count  \
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 4                              Spider-Man 3           5.9        3576
#
#    director_id  year month       day
# 0         4762  2009   Dec  Thursday
# 1         4763  2007   May  Saturday
# 2         4764  2015   Oct    Monday
# 3         4765  2012   Jul    Monday
# ...

# %%
movies = pd.read_csv('movies.csv', index_col=False)
movies.head()
# Out:
#    Unnamed: 0     id     budget  popularity     revenue  \
# 0           0  43597  237000000         150  2787965087
# 1           1  43598  300000000         139   961000000
# 2           2  43599  245000000         107   880674609
# 3           3  43600  250000000         112  1084939099
# 4           5  43602  258000000         115   890871626
#
#                                       title  vote_average  vote_count  \
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 4                              Spider-Man 3           5.9        3576
#
#    director_id  year month       day
# 0         4762  2009   Dec  Thursday
# 1         4763  2007   May  Saturday
# 2         4764  2015   Oct    Monday
# 3         4765  2012   Jul    Monday
# ...

# %%
movies.columns
# Out:
# Index(['Unnamed: 0', 'id', 'budget', 'popularity', 'revenue', 'title',
#        'vote_average', 'vote_count', 'director_id', 'year', 'month', 'day'],
#       dtype='object')

# %%
movies.columns[0]
# Out:
# 'Unnamed: 0'

# %%
movies.columns.get_loc('id')
# Out:
# 1

# %%
movies = pd.read_csv('movies.csv', index_col=0)
movies.head()
# Out:
#       id     budget  popularity     revenue  \
# 0  43597  237000000         150  2787965087
# 1  43598  300000000         139   961000000
# 2  43599  245000000         107   880674609
# 3  43600  250000000         112  1084939099
# 5  43602  258000000         115   890871626
#
#                                       title  vote_average  vote_count  \
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 5                              Spider-Man 3           5.9        3576
#
#    director_id  year month       day
# 0         4762  2009   Dec  Thursday
# 1         4763  2007   May  Saturday
# 2         4764  2015   Oct    Monday
# 3         4765  2012   Jul    Monday
# 5         4767  2007   May   Tuesday

# %%
data = {'marks': {0: 97,   1: 63,   2: 63,   3: 71,   4: 64,   5: 90,   6: 66,   7: 46,   8: 74,   9: 62,   10: 94,   11: 67},  'roll_no': {0: 1,   1: 2,   2: 1,   3: 3,   4: 1,   5: 3,   6: 3,   7: 3,   8: 2,   9: 2,   10: 1,   11: 2},  'subject': {0: 'NN',   1: 'DL',   2: 'ML',   3: 'Prob',   4: 'DL',   5: 'ML',   6: 'DL',   7: 'NN',   8: 'NN',   9: 'Prob',   10: 'Prob',   11: 'ML'}}

df = pd.DataFrame(data)

# %%
df.head()
# Out:
#    marks  roll_no subject
# 0     97        1      NN
# 1     63        2      DL
# 2     63        1      ML
# 3     71        3    Prob
# 4     64        1      DL

# %%
df.groupby('subject')['marks'].max()
# Out:
# subject
# DL      66
# ML      90
# NN      97
# Prob    94
# Name: marks, dtype: int64

# %%
df.isin(df.roll_no)
# Out:
#     roll_no  subject  marks
# 0      True    False  False
# 1      True    False  False
# 2      True    False  False
# 3      True    False  False
# 4      True    False  False
# 5      True    False  False
# 6      True    False  False
# 7      True    False  False
# 8      True    False  False
# 9      True    False  False
# 10     True    False  False
# 11     True    False  False

# %%
df['marks'].apply(lambda x:print(x))
# Out:
# 97
# 63
# 63
# 71
# 64
# 90
# 66
# 46
# 74
# 62
# 94
# 67
# 0     None
# 1     None
# 2     None
# 3     None
# 4     None
# 5     None
# 6     None
# 7     None
# 8     None
# 9     None
# 10    None
# 11    None
# Name: marks, dtype: object

# %%
def get_all(x):
  print(x)
  return x[x.max()==x]

def get_all(x):
  print(x)
  return x[x.max()==x]

# %%
df.groupby('subject')['marks'].max()
# Out:
# 1    63
# 4    64
# 6    66
# Name: marks, dtype: int64
# 2     63
# 5     90
# 11    67
# Name: marks, dtype: int64
# 0    97
# 7    46
# 8    74
# Name: marks, dtype: int64
# 3     71
# 9     62
# 10    94
# Name: marks, dtype: int64
# 1    2
# 4    1
# 6    3
# Name: roll_no, dtype: int64
# 2     1
# 5     3
# 11    2
# Name: roll_no, dtype: int64
# 0    1
# 7    3
# 8    2
# Name: roll_no, dtype: int64
# 3     3
# 9     2
# 10    1
# Name: roll_no, dtype: int64
#           marks roll_no
#         get_all get_all
# subject
# DL           66       3
# ML           90       3
# NN           97       3
# Prob         94       3

# %%
df.loc[df.groupby('subject')['marks'].idxmax()][['subject','marks','roll_no']].reset_index(drop=True)
# Out:
#   subject  marks  roll_no
# 0      DL     66        3
# 1      ML     90        3
# 2      NN     97        1
# 3    Prob     94        1

# %%
movies.shape
# Out:
# (1465, 11)

# %%
directors = pd.read_csv('directors.csv',index_col=0)
directors.head()
# Out:
#        director_name    id gender
# 0      James Cameron  4762   Male
# 1     Gore Verbinski  4763   Male
# 2         Sam Mendes  4764   Male
# 3  Christopher Nolan  4765   Male
# 4     Andrew Stanton  4766   Male

# %%
directors.shape
# Out:
# (2349, 3)

# %%
movies['director_id'].nunique()
# Out:
# 199

# %%
sum(movies['director_id'].isin(directors.id)==False)
# Out:
# 0

# %%
movies['director_id'].unique()
# Out:
# array([4762, 4763, 4764, 4765, 4767, 4771, 4772, 4773, 4774, 4775, 4776,
#        4777, 4779, 4780, 4782, 4785, 4786, 4788, 4791, 4793, 4794, 4797,
#        4798, 4799, 4802, 4803, 4804, 4805, 4808, 4809, 4810, 4811, 4812,
#        4813, 4814, 4829, 4831, 4832, 4833, 4838, 4839, 4842, 4845, 4846,
#        4847, 4849, 4854, 4857, 4858, 4859, 4863, 4865, 4866, 4867, 4868,
#        4872, 4873, 4874, 4876, 4880, 4881, 4885, 4886, 4888, 4889, 4890,
#        4892, 4893, 4894, 4900, 4904, 4909, 4913, 4915, 4917, 4918, 4921,
#        4923, 4924, 4925, 4926, 4927, 4930, 4935, 4936, 4945, 4947, 4948,
#        4949, 4955, 4958, 4960, 4964, 4965, 4967, 4974, 4978, 4989, 4991,
#        4993, 4995, 4998, 5002, 5005, 5008, 5009, 5014, 5017, 5024, 5031,
#        5033, 5034, 5035, 5037, 5039, 5047, 5053, 5056, 5059, 5061, 5067,
#        5082, 5087, 5088, 5093, 5096, 5097, 5101, 5105, 5111, 5113, 5115,
#        5116, 5123, 5125, 5130, 5132, 5135, 5140, 5147, 5148, 5152, 5157,
# ...

# %%
directors['id'].nunique()
# Out:
# 2349

# %%
movies['director_id'].isin(directors['id'])
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 5       True
#         ...
# 4736    True
# 4743    True
# 4748    True
# 4749    True
# 4768    True
# Name: director_id, Length: 1465, dtype: bool

# %%
np.all(movies['director_id'].isin(directors['id']))
# Out:
# True

# %%
data = movies.merge(directors, how='left', left_on='director_id', right_on='id')
data
# Out:
#        id_x     budget  popularity     revenue  \
# 0     43597  237000000         150  2787965087
# 1     43598  300000000         139   961000000
# 2     43599  245000000         107   880674609
# 3     43600  250000000         112  1084939099
# 4     43602  258000000         115   890871626
# ...     ...        ...         ...         ...
# 1460  48363          0           3      321952
# 1461  48370      27000          19     3151130
# 1462  48375          0           7           0
# 1463  48376          0           3           0
# 1464  48395     220000          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# ...

# %%
data.drop(['director_id','id_y'],axis=1,inplace=True)
data.head()
# Out:
#     id_x     budget  popularity     revenue  \
# 0  43597  237000000         150  2787965087
# 1  43598  300000000         139   961000000
# 2  43599  245000000         107   880674609
# 3  43600  250000000         112  1084939099
# 4  43602  258000000         115   890871626
#
#                                       title  vote_average  vote_count  year  \
# 0                                    Avatar           7.2       11800  2009
# 1  Pirates of the Caribbean: At World's End           6.9        4500  2007
# 2                                   Spectre           6.3        4466  2015
# 3                     The Dark Knight Rises           7.6        9106  2012
# 4                              Spider-Man 3           5.9        3576  2007
#
#   month       day      director_name gender
# 0   Dec  Thursday      James Cameron   Male
# 1   May  Saturday     Gore Verbinski   Male
# 2   Oct    Monday         Sam Mendes   Male
# 3   Jul    Monday  Christopher Nolan   Male
# ...

# %%
data = data.rename(columns={'id_x':'id'})
data.head()
# Out:
#       id     budget  popularity     revenue  \
# 0  43597  237000000         150  2787965087
# 1  43598  300000000         139   961000000
# 2  43599  245000000         107   880674609
# 3  43600  250000000         112  1084939099
# 4  43602  258000000         115   890871626
#
#                                       title  vote_average  vote_count  year  \
# 0                                    Avatar           7.2       11800  2009
# 1  Pirates of the Caribbean: At World's End           6.9        4500  2007
# 2                                   Spectre           6.3        4466  2015
# 3                     The Dark Knight Rises           7.6        9106  2012
# 4                              Spider-Man 3           5.9        3576  2007
#
#   month       day      director_name gender
# 0   Dec  Thursday      James Cameron   Male
# 1   May  Saturday     Gore Verbinski   Male
# 2   Oct    Monday         Sam Mendes   Male
# 3   Jul    Monday  Christopher Nolan   Male
# ...

# %%
#Quiz 1

# %% [markdown]
# How to filter those records where movies are released either in the year 2015, 2016 or 2012 from the movies dataset?

# %%
#df['year'].isin([2015, 2016, 2012])

# %%
years_to_filter = [2015, 2016, 2012]

# %%
movies[movies['year'].isin(years_to_filter)]
# Out:
#          id     budget  popularity     revenue  \
# 2     43599  245000000         107   880674609
# 3     43600  250000000         112  1084939099
# 9     43606  250000000         155   873260194
# 18    43615  225000000          52   624026776
# 27    43624  209000000          64   303025485
# ...     ...        ...         ...         ...
# 3743  47343    4000000          24    52425855
# 3974  47575    3000000           3           0
# 4115  47719   13500000           5      187674
# 4532  48146          0          10      316472
# 4540  48155          0           0           0
#
#                                    title  vote_average  vote_count  \
# 2                                Spectre           6.3        4466
# 3                  The Dark Knight Rises           7.6        9106
# 9     Batman v Superman: Dawn of Justice           5.7        7004
# 18                        Men in Black 3           6.2        4160
# ...

# %%
data.head()
# Out:
#       id     budget  popularity     revenue  \
# 0  43597  237000000         150  2787965087
# 1  43598  300000000         139   961000000
# 2  43599  245000000         107   880674609
# 3  43600  250000000         112  1084939099
# 4  43602  258000000         115   890871626
#
#                                       title  vote_average  vote_count  year  \
# 0                                    Avatar           7.2       11800  2009
# 1  Pirates of the Caribbean: At World's End           6.9        4500  2007
# 2                                   Spectre           6.3        4466  2015
# 3                     The Dark Knight Rises           7.6        9106  2012
# 4                              Spider-Man 3           5.9        3576  2007
#
#   month       day      director_name gender
# 0   Dec  Thursday      James Cameron   Male
# 1   May  Saturday     Gore Verbinski   Male
# 2   Oct    Monday         Sam Mendes   Male
# 3   Jul    Monday  Christopher Nolan   Male
# ...

# %%
def encode(data):
  if data == 'Male':
    return 0
  else:
    return 1

# %%
data['gender'] = data['gender'].apply(encode)
data.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-5bca6d04baf8> in <cell line: 1>()
# ----> 1 data['gender'] = data['gender'].apply(encode)
#       2 data.head()
#
# NameError: name 'encode' is not defined

# %%
data[['revenue','budget']].apply(np.sum, axis = 1)
# Out:
# 0       3024965087
# 1       1261000000
# 2       1125674609
# 3       1334939099
# 4       1148871626
#            ...
# 1460        321952
# 1461       3178130
# 1462             0
# 1463             0
# 1464       2260920
# Length: 1465, dtype: int64

# %%
def prof(x):
  return x['revenue'] - x['budget']

data['profit'] = data[['revenue','budget']].apply(prof, axis = 1)
data.head()
# Out:
#       id     budget  popularity     revenue  \
# 0  43597  237000000         150  2787965087
# 1  43598  300000000         139   961000000
# 2  43599  245000000         107   880674609
# 3  43600  250000000         112  1084939099
# 4  43602  258000000         115   890871626
#
#                                       title  vote_average  vote_count  year  \
# 0                                    Avatar           7.2       11800  2009
# 1  Pirates of the Caribbean: At World's End           6.9        4500  2007
# 2                                   Spectre           6.3        4466  2015
# 3                     The Dark Knight Rises           7.6        9106  2012
# 4                              Spider-Man 3           5.9        3576  2007
#
#   month       day      director_name  gender      profit
# 0   Dec  Thursday      James Cameron       0  2550965087
# 1   May  Saturday     Gore Verbinski       0   661000000
# 2   Oct    Monday         Sam Mendes       0   635674609
# ...

# %%
type(data.groupby('director_name'))
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
data.groupby('director_name').ngroups
# Out:
# 199

# %%
data.groupby('director_name').groups
# Out:
# {'Adam McKay': [176, 323, 366, 505, 839, 916], 'Adam Shankman': [265, 300, 350, 404, 458, 843, 999, 1231], 'Alejandro González Iñárritu': [106, 749, 1015, 1034, 1077, 1405], 'Alex Proyas': [95, 159, 514, 671, 873], 'Alexander Payne': [793, 1006, 1101, 1211, 1281], 'Andrew Adamson': [11, 43, 328, 501, 947], 'Andrew Niccol': [533, 603, 701, 722, 1439], 'Andrzej Bartkowiak': [349, 549, 754, 911, 924], 'Andy Fickman': [517, 681, 909, 926, 973, 1023], 'Andy Tennant': [314, 320, 464, 593, 676, 885], 'Ang Lee': [99, 134, 748, 840, 1089, 1110, 1132, 1184], 'Anne Fletcher': [610, 650, 736, 789, 1206], 'Antoine Fuqua': [310, 338, 424, 467, 576, 808, 818, 1105], 'Atom Egoyan': [946, 1128, 1164, 1194, 1347, 1416], 'Barry Levinson': [313, 319, 471, 594, 878, 898, 1013, 1037, 1082, 1143, 1185, 1345, 1378], 'Barry Sonnenfeld': [13, 48, 90, 205, 591, 778, 783], 'Ben Stiller': [209, 212, 547, 562, 850], 'Bill Condon': [102, 307, 902, 1233, 1381], 'Bobby Farrelly': [352, 356, 481, 498, 624, 630, 654, 
# ...

# %%
data.groupby('director_name').get_group('Alexander Payne')
# Out:
#          id    budget  popularity    revenue            title  vote_average  \
# 793   45163  30000000          19  105834556    About Schmidt           6.7
# 1006  45699  20000000          40  177243185  The Descendants           6.7
# 1101  46004  16000000          23  109502303         Sideways           6.9
# 1211  46446  12000000          29   17654912         Nebraska           7.4
# 1281  46813         0          13          0         Election           6.7
#
#       vote_count  year month       day    director_name  gender     profit
# 793          362  2002   Dec    Friday  Alexander Payne       1   75834556
# 1006         934  2011   Sep    Friday  Alexander Payne       1  157243185
# 1101         478  2004   Oct    Friday  Alexander Payne       1   93502303
# 1211         636  2013   Sep  Saturday  Alexander Payne       1    5654912
# 1281         270  1999   Apr    Friday  Alexander Payne       1          0

# %%
data.groupby('director_name')['title'].nunique()
# Out:
# director_name
# Adam McKay                      6
# Adam Shankman                   8
# Alejandro González Iñárritu     6
# Alex Proyas                     5
# Alexander Payne                 5
#                                ..
# Wes Craven                     10
# Wolfgang Petersen               7
# Woody Allen                    18
# Zack Snyder                     7
# Zhang Yimou                     6
# Name: title, Length: 199, dtype: int64

# %%
data.groupby('director_name')['title'].aggregate('count')
# Out:
# director_name
# Adam McKay                      6
# Adam Shankman                   8
# Alejandro González Iñárritu     6
# Alex Proyas                     5
# Alexander Payne                 5
#                                ..
# Wes Craven                     10
# Wolfgang Petersen               7
# Woody Allen                    18
# Zack Snyder                     7
# Zhang Yimou                     6
# Name: title, Length: 199, dtype: int64

# %%
data.groupby('director_name')['year'].aggregate(['min','max','count'])
# Out:
#                               min   max  count
# director_name
# Adam McKay                   2004  2015      6
# Adam Shankman                2001  2012      8
# Alejandro González Iñárritu  2000  2015      6
# Alex Proyas                  1994  2016      5
# Alexander Payne              1999  2013      5
# ...                           ...   ...    ...
# Wes Craven                   1984  2011     10
# Wolfgang Petersen            1981  2006      7
# Woody Allen                  1977  2013     18
# Zack Snyder                  2004  2016      7
# Zhang Yimou                  2002  2014      6
#
# [199 rows x 3 columns]

# %%
data.head()
# Out:
#       id     budget  popularity     revenue  \
# 0  43597  237000000         150  2787965087
# 1  43598  300000000         139   961000000
# 2  43599  245000000         107   880674609
# 3  43600  250000000         112  1084939099
# 4  43602  258000000         115   890871626
#
#                                       title  vote_average  vote_count  year  \
# 0                                    Avatar           7.2       11800  2009
# 1  Pirates of the Caribbean: At World's End           6.9        4500  2007
# 2                                   Spectre           6.3        4466  2015
# 3                     The Dark Knight Rises           7.6        9106  2012
# 4                              Spider-Man 3           5.9        3576  2007
#
#   month       day      director_name gender
# 0   Dec  Thursday      James Cameron   Male
# 1   May  Saturday     Gore Verbinski   Male
# 2   Oct    Monday         Sam Mendes   Male
# 3   Jul    Monday  Christopher Nolan   Male
# ...

# %%
#Quiz 2

# %%
#data.groupby('emp_id').mean()

# %%
employee_data = pd.DataFrame({
    'emp_id': [101, 102, 103, 104, 105, 101, 102, 103, 104, 105],
    'monthly_rating': [4.5, 3.8, 4.2, 5.0, 4.0, 4.6, 3.9, 4.3, 4.9, 4.1],
    'bonus': [100, 150, 200, 250, 300, 120, 160, 210, 260, 310]
})

employee_data
# Out:
#    emp_id  monthly_rating  bonus
# 0     101             4.5    100
# 1     102             3.8    150
# 2     103             4.2    200
# 3     104             5.0    250
# 4     105             4.0    300
# 5     101             4.6    120
# 6     102             3.9    160
# 7     103             4.3    210
# 8     104             4.9    260
# 9     105             4.1    310

# %%
employee_data.groupby('emp_id')['monthly_rating'].mean() #employee id as the index
# Out:
# emp_id
# 101    4.55
# 102    3.85
# 103    4.25
# 104    4.95
# 105    4.05
# Name: monthly_rating, dtype: float64

# %%
employee_data.groupby('emp_id')['monthly_rating']

# %%
type(employee_data.groupby('emp_id')['monthly_rating'].mean())
# Out:
# pandas.core.series.Series

# %%
type(employee_data.groupby('emp_id')['monthly_rating'].mean().reset_index())
# Out:
# pandas.core.frame.DataFrame

# %%
employee_data.groupby('emp_id').mean().reset_index()
# Out:
#    emp_id  monthly_rating  bonus
# 0     101            4.55  110.0
# 1     102            3.85  155.0
# 2     103            4.25  205.0
# 3     104            4.95  255.0
# 4     105            4.05  305.0

# %%
type(employee_data.groupby('emp_id').mean())
# Out:
# pandas.core.frame.DataFrame

# %%
employee_data.groupby('monthly_rating').mean()
# Out:
#                 emp_id  bonus
# monthly_rating
# 3.8              102.0  150.0
# 3.9              102.0  160.0
# 4.0              105.0  300.0
# 4.1              105.0  310.0
# 4.2              103.0  200.0
# 4.3              103.0  210.0
# 4.5              101.0  100.0
# 4.6              101.0  120.0
# 4.9              104.0  260.0
# 5.0              104.0  250.0

# %%
employee_data.groupby('emp_id')

# %%
employee_data.groupby('monthly_rating')

# %%
data
# Out:
#          id     budget  popularity     revenue  \
# 0     43597  237000000         150  2787965087
# 1     43598  300000000         139   961000000
# 2     43599  245000000         107   880674609
# 3     43600  250000000         112  1084939099
# 4     43602  258000000         115   890871626
# ...     ...        ...         ...         ...
# 1460  48363          0           3      321952
# 1461  48370      27000          19     3151130
# 1462  48375          0           7           0
# 1463  48376          0           3           0
# 1464  48395     220000          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# ...

# %%
#Quiz 3

#A - It will give an error since we can't aggregate string columns like "title" using mean.

# %%
data.groupby('director_name').mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/groupby.py in _agg_py_fallback(self, how, values, ndim, alt)
#    1941         try:
# -> 1942             res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943         except Exception as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/ops.py in agg_series(self, obj, func, preserve_dtype)
#     863
# --> 864         result = self._aggregate_series_pure_python(obj, func)
#     865
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/ops.py in _aggregate_series_pure_python(self, obj, func)
#     884         for i, group in enumerate(splitter):
# --> 885             res = func(group)
#     886             res = extract_result(res)
#
# ...

# %%
numeric_data = data.select_dtypes(include=['number'])

# %%
numeric_data.groupby(data['director_name']).mean()
# Out:
#                                        id        budget  popularity  \
# director_name
# Adam McKay                   44586.000000  5.691667e+07   30.333333
# Adam Shankman                44821.250000  4.837500e+07   23.125000
# Alejandro González Iñárritu  45660.500000  3.333333e+07   47.000000
# Alex Proyas                  44477.000000  7.040000e+07   53.200000
# Alexander Payne              46025.000000  1.560000e+07   24.800000
# ...                                   ...           ...         ...
# Wes Craven                   45503.300000  2.338000e+07   22.300000
# Wolfgang Petersen            44511.285714  9.014286e+07   35.857143
# Woody Allen                  46083.777778  1.177778e+07   17.722222
# Zack Snyder                  44086.857143  1.228571e+08   71.857143
# Zhang Yimou                  45630.166667  2.083335e+07   12.000000
#
#                                   revenue  vote_average   vote_count  \
# director_name
# ...

# %%
#Quiz 4
#For each year, how you will get the average, lowest, and highest value of movie ratings?

#data.groupby('year').agg({'vote_average': ['mean', 'min', 'max']})

# %%
data.groupby('year').agg({'vote_average': ['mean', 'min', 'max']})
# Out:
#      vote_average
#              mean  min  max
# year
# 1976     7.633333  7.2  8.0
# 1977     6.900000  6.1  7.8
# 1978     7.020000  5.9  7.9
# 1979     7.025000  5.6  8.0
# 1980     7.187500  6.4  7.9
# 1981     6.927273  6.0  7.9
# 1982     6.810000  5.5  7.9
# 1983     6.666667  4.5  8.0
# 1984     6.760000  6.1  7.3
# 1985     6.885714  5.9  8.0
# 1986     6.809091  5.8  7.8
# 1987     6.991667  6.1  7.6
# 1988     6.692308  5.7  7.6
# 1989     6.750000  5.5  7.6
# 1990     6.661111  5.8  8.2
# 1991     7.100000  6.6  8.1
# 1992     6.640909  5.7  8.0
# 1993     7.144444  6.1  8.3
# 1994     6.596774  5.0  8.3
# 1995     6.509091  4.5  8.1
# 1996     6.384783  5.4  7.8
# 1997     6.552174  4.1  7.9
# 1998     6.442222  4.9  7.9
# 1999     6.384375  5.1  8.3
# 2000     6.347458  4.4  8.1
# 2001     6.217742  3.7  8.0
# 2002     6.359420  3.4  8.0
# 2003     6.115517  4.4  8.1
# 2004     6.427869  4.7  7.7
# 2005     6.229577  3.1  7.7
# 2006     6.212329  3.6  8.0
# ...

# %%
data.groupby('year').agg(['mean', 'min', 'max'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/groupby.py in _agg_py_fallback(self, how, values, ndim, alt)
#    1941         try:
# -> 1942             res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943         except Exception as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/ops.py in agg_series(self, obj, func, preserve_dtype)
#     863
# --> 864         result = self._aggregate_series_pure_python(obj, func)
#     865
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/ops.py in _aggregate_series_pure_python(self, obj, func)
#     884         for i, group in enumerate(splitter):
# --> 885             res = func(group)
#     886             res = extract_result(res)
#
# ...

# %%
data.groupby('year').agg({'vote_average': ['mean', 'min', 'max']})
# Out:
#      vote_average
#              mean  min  max
# year
# 1976     7.633333  7.2  8.0
# 1977     6.900000  6.1  7.8
# 1978     7.020000  5.9  7.9
# 1979     7.025000  5.6  8.0
# 1980     7.187500  6.4  7.9
# 1981     6.927273  6.0  7.9
# 1982     6.810000  5.5  7.9
# 1983     6.666667  4.5  8.0
# 1984     6.760000  6.1  7.3
# 1985     6.885714  5.9  8.0
# 1986     6.809091  5.8  7.8
# 1987     6.991667  6.1  7.6
# 1988     6.692308  5.7  7.6
# 1989     6.750000  5.5  7.6
# 1990     6.661111  5.8  8.2
# 1991     7.100000  6.6  8.1
# 1992     6.640909  5.7  8.0
# 1993     7.144444  6.1  8.3
# 1994     6.596774  5.0  8.3
# 1995     6.509091  4.5  8.1
# 1996     6.384783  5.4  7.8
# 1997     6.552174  4.1  7.9
# 1998     6.442222  4.9  7.9
# 1999     6.384375  5.1  8.3
# 2000     6.347458  4.4  8.1
# 2001     6.217742  3.7  8.0
# 2002     6.359420  3.4  8.0
# 2003     6.115517  4.4  8.1
# 2004     6.427869  4.7  7.7
# 2005     6.229577  3.1  7.7
# 2006     6.212329  3.6  8.0
# ...

# %%
data.groupby('year')['vote_average'].agg(['mean', 'min', 'max'])
# Out:
#           mean  min  max
# year
# 1976  7.633333  7.2  8.0
# 1977  6.900000  6.1  7.8
# 1978  7.020000  5.9  7.9
# 1979  7.025000  5.6  8.0
# 1980  7.187500  6.4  7.9
# 1981  6.927273  6.0  7.9
# 1982  6.810000  5.5  7.9
# 1983  6.666667  4.5  8.0
# 1984  6.760000  6.1  7.3
# 1985  6.885714  5.9  8.0
# 1986  6.809091  5.8  7.8
# 1987  6.991667  6.1  7.6
# 1988  6.692308  5.7  7.6
# 1989  6.750000  5.5  7.6
# 1990  6.661111  5.8  8.2
# 1991  7.100000  6.6  8.1
# 1992  6.640909  5.7  8.0
# 1993  7.144444  6.1  8.3
# 1994  6.596774  5.0  8.3
# 1995  6.509091  4.5  8.1
# 1996  6.384783  5.4  7.8
# 1997  6.552174  4.1  7.9
# 1998  6.442222  4.9  7.9
# 1999  6.384375  5.1  8.3
# 2000  6.347458  4.4  8.1
# 2001  6.217742  3.7  8.0
# 2002  6.359420  3.4  8.0
# 2003  6.115517  4.4  8.1
# 2004  6.427869  4.7  7.7
# 2005  6.229577  3.1  7.7
# 2006  6.212329  3.6  8.0
# 2007  6.307407  3.2  7.9
# 2008  6.268657  3.0  8.2
# 2009  6.190909  3.9  7.9
# 2010  6.223810  4.2  8.1
# ...

# %%
#Option C
data.groupby('year').agg(('vote_average': ['mean', 'min', 'max']))
# Out:
#   File "<ipython-input-147-9aeb89ee9d90>", line 2
#     data.groupby('year').agg(('vote_average': ['mean', 'min', 'max']))
#                                             ^
# SyntaxError: invalid syntax

# %%
#Group based filtering

# %%
data.head()
# Out:
#       id     budget  popularity     revenue  \
# 0  43597  237000000         150  2787965087
# 1  43598  300000000         139   961000000
# 2  43599  245000000         107   880674609
# 3  43600  250000000         112  1084939099
# 4  43602  258000000         115   890871626
#
#                                       title  vote_average  vote_count  year  \
# 0                                    Avatar           7.2       11800  2009
# 1  Pirates of the Caribbean: At World's End           6.9        4500  2007
# 2                                   Spectre           6.3        4466  2015
# 3                     The Dark Knight Rises           7.6        9106  2012
# 4                              Spider-Man 3           5.9        3576  2007
#
#   month       day      director_name  gender      profit
# 0   Dec  Thursday      James Cameron       0  2550965087
# 1   May  Saturday     Gore Verbinski       0   661000000
# 2   Oct    Monday         Sam Mendes       0   635674609
# ...

# %%
data_dir_budget = data.groupby("director_name")["budget"].max().reset_index()
data_dir_budget.head()
# Out:
#                  director_name     budget
# 0                   Adam McKay  100000000
# 1                Adam Shankman   80000000
# 2  Alejandro González Iñárritu  135000000
# 3                  Alex Proyas  140000000
# 4              Alexander Payne   30000000

# %%
names = data_dir_budget.loc[data_dir_budget['budget'] > 100, "director_name"]
names
# Out:
# 0                       Adam McKay
# 1                    Adam Shankman
# 2      Alejandro González Iñárritu
# 3                      Alex Proyas
# 4                  Alexander Payne
#                   ...
# 194                     Wes Craven
# 195              Wolfgang Petersen
# 196                    Woody Allen
# 197                    Zack Snyder
# 198                    Zhang Yimou
# Name: director_name, Length: 199, dtype: object

# %%
data.loc[data['director_name'].isin(names)]
# Out:
#          id     budget  popularity     revenue  \
# 0     43597  237000000         150  2787965087
# 1     43598  300000000         139   961000000
# 2     43599  245000000         107   880674609
# 3     43600  250000000         112  1084939099
# 4     43602  258000000         115   890871626
# ...     ...        ...         ...         ...
# 1460  48363          0           3      321952
# 1461  48370      27000          19     3151130
# 1462  48375          0           7           0
# 1463  48376          0           3           0
# 1464  48395     220000          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# ...

# %%
data.groupby('director_name').filter(lambda x: x['budget'].max() > 100)
# Out:
#          id     budget  popularity     revenue  \
# 0     43597  237000000         150  2787965087
# 1     43598  300000000         139   961000000
# 2     43599  245000000         107   880674609
# 3     43600  250000000         112  1084939099
# 4     43602  258000000         115   890871626
# ...     ...        ...         ...         ...
# 1460  48363          0           3      321952
# 1461  48370      27000          19     3151130
# 1462  48375          0           7           0
# 1463  48376          0           3           0
# 1464  48395     220000          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# ...

# %%
#group based apply

def func(x):
  # returns whether a movie is risky or not
  x["risky"] = x["budget"] - x["revenue"].mean() >= 0
  return x

# %%
data_risky = data.groupby("director_name", group_keys=False).apply(func)
data_risky
# Out:
# <ipython-input-28-28f34173ecf8>:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   data_risky = data.groupby("director_name", group_keys=False).apply(func)
#          id     budget  popularity     revenue  \
# 0     43597  237000000         150  2787965087
# 1     43598  300000000         139   961000000
# 2     43599  245000000         107   880674609
# 3     43600  250000000         112  1084939099
# 4     43602  258000000         115   890871626
# ...     ...        ...         ...         ...
# 1460  48363          0           3      321952
# 1461  48370      27000          19     3151130
# 1462  48375          0           7           0
# 1463  48376          0           3           0
# ...

# %%
data.groupby("director_name", group_keys=True).apply(func)
# Out:
# <ipython-input-161-f7af3cbb1caf>:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   data.groupby("director_name", group_keys=True).apply(func)
#                        id     budget  popularity    revenue  \
# director_name
# Adam McKay    176   43882  100000000          24  170432927
#               323   44151   72500000          12  162966177
#               366   44236   65000000          22  128107642
#               505   44503   50000000          38  173649015
#               839   45301   28000000          57  133346506
# ...                   ...        ...         ...        ...
# Zhang Yimou   590   44692        110           9          0
# ...

# %%
data_risky.loc[data_risky["risky"]]
# Out:
#          id     budget  popularity     revenue  \
# 7     43608  200000000         107   586090727
# 12    43614  380000000         135  1045713802
# 15    43618  200000000          37   310669540
# 20    43624  209000000          64   303025485
# 24    43630  210000000           3   459359555
# ...     ...        ...         ...         ...
# 1347  47224    5000000           7     3263585
# 1349  47229    5000000           3     4842699
# 1351  47233    5000000           6           0
# 1356  47263   15000000          10           0
# 1383  47453    3500000           4           0
#
#                                             title  vote_average  vote_count  \
# 7                               Quantum of Solace           6.1        2965
# 12    Pirates of the Caribbean: On Stranger Tides           6.4        4948
# 15                                     Robin Hood           6.2        1398
# 20                                     Battleship           5.5        2114
# ...

# %%
data
# Out:
#          id     budget  popularity     revenue  \
# 0     43597  237000000         150  2787965087
# 1     43598  300000000         139   961000000
# 2     43599  245000000         107   880674609
# 3     43600  250000000         112  1084939099
# 4     43602  258000000         115   890871626
# ...     ...        ...         ...         ...
# 1460  48363          0           3      321952
# 1461  48370      27000          19     3151130
# 1462  48375          0           7           0
# 1463  48376          0           3           0
# 1464  48395     220000          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# ...

# %%
#Quiz 5
data1 = {'Group': ['G1', 'G2', 'G2', 'G3', 'G3', 'G3'],
        'Points': [2, 4, 6, 8, 10, 12]}
df = pd.DataFrame(data1)

# %%
result = df.groupby('Group')['Points'].apply(lambda x: x.sum())
print(result)
# Out:
# Group
# G1     2
# G2    10
# G3    30
# Name: Points, dtype: int64
