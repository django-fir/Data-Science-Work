# %%
import requests

url = "https://bpprod2linear.akamaized.net/bpk-tv/irdeto_com_Channel_258/output/manifest.mpd"
headers = {
    "Accept-Encoding": "gzip",
    "Connection": "Keep-Alive",
    "Host": "bpprod2linear.akamaized.net",
    "User-Agent": "TiviMate/4.6.1 (Linux; Android 9)"
}

try:
    response = requests.get(url, headers=headers)

    # Check if the request was successful (status code 200)
    if response.status_code == 200:
        print("Request successful")
        print(response.text)
    else:
        print(f"Request failed with status code: {response.status_code}")
except requests.RequestException as e:
    print(f"Error: {e}")

# %%
import requests

headers = {
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8',
    'Accept-Language': 'en-US,en;q=0.8',
    'Connection': 'keep-alive',
    'Sec-Fetch-Dest': 'document',
    'Sec-Fetch-Mode': 'navigate',
    'Sec-Fetch-Site': 'none',
    'Sec-Fetch-User': '?1',
    'Sec-GPC': '1',
    'Upgrade-Insecure-Requests': '1',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36',
    'sec-ch-ua': '"Not_A Brand";v="8", "Chromium";v="120", "Brave";v="120"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
}

response = requests.get(
    'https://bpprod2linear.akamaized.net/bpk-tv/irdeto_com_Channel_258/output/manifest.mpd',
    headers=headers,
)

# %%
url = "https://bpprod6linear.akamaized.net/bpk-tv/irdeto_com_Channel_609/output/dash/STAR_Maa_HD-video=877600-213101905.m4s"

# %%
res = requests.get(url)

# %%
res

# %%
import requests

# %%
url = "https://api.vtuconnect.in/v2/result/1VI20CS113"
surl = "https://api.vtuconnect.in/v2/result/sem?usn=1VI20cs113&yearmonth=May/June/July%202023&sem=6"

# %%
headders = {
    "User-Agent":"Dalvik/2.1.0 (Linux; U; Android 11; 2107113SI Build/SKQ1.211006.001)",
    "Authorization":"Bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.....Tyfy1hMtRKL2q6sPJ5nMWk9HOAS5BqmueVptBuEGluo"
}

# %%
res = requests.get(url,headers=headders)
res.json()

# %%
dates = []
for i in res.json():
  if i["semester"] == '1':
    dates.append(i["resultMonthYear"])
for i in dates:

# %%
"""[{'_id': '615971acc1409809fbcec927',
  'resultMonthYear': 'JANUARY/FEBRUARY/MARCH 2021',
  'semester': '1',
  'usn': '1VI20CS113',
  'name': 'SURAPALLY SUDHARSHAN REDDY',
  'status': 'Fail',
  'total': 453},"""
url_c =
urls = []
for i in res.json():
  a = "sem?usn={}&yearmonth={}&sem={}".format(i["usn"],i["resultMonthYear"],i["semester"])
  urls.append(a)

urls

# %%
surl = 'https://api.vtuconnect.in/v2/result/'+urls[0]

# %%
sres = requests.get(surl,headers=headders)

# %%
sres.json()

# %%
import requests

# %%
""""{Accept-Encoding":"gzip",
"Connection":"Keep-Alive",
"Content-Length":"54",}
"""
h = {
    "User-Agent":"Dalvik/2.1.0 (Linux; U; Android 11; 2107113SI Build/SKQ1.211006.001)"
}

# %%
url = "https://bolt.toxic-gang.xyz/tata/key.php?id=516"

# %%
data = {
  "kids": [
    "sunyHzaHXqe8XSguU__cIg"
  ],
  "type": "temporary"
}

# %%
res = requests.post(url,headers=h,data=data)

# %%
res.json()

# %%
from cryptography.hazmat.primitives.ciphers import Cipher, algorithms, modes
from cryptography.hazmat.backends import default_backend

def decrypt_oct(key, ciphertext):
    backend = default_backend()
    cipher = Cipher(algorithms.XChaCha20(key), mode=None, backend=backend)
    decryptor = cipher.decryptor()
    plaintext = decryptor.update(ciphertext) + decryptor.finalize()
    return plaintext

# Replace these values with your actual key and encrypted content
key = b'RUcOKMF6Of278vJQK7mW5g'
encrypted_content = b'your_encrypted_content_here'

decrypted_content = decrypt_oct(key, encrypted_content)

with open('decrypted_video.mp4', 'wb') as decrypted_file:
    decrypted_file.write(decrypted_content)
