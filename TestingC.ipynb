# %%
#include<stdio.h>
#include<stdlib.h>
int a[10],i,n,ele,pos;
void create()
{
printf("enter the size of array elements\n ");
scanf("%d,&n);
printf("enter the array elements\n");
for(i=0;i<n;i++)
scanf("%d",&a[i]);
}
void main()
{
 create();

}
# Out:
#   File "<ipython-input-3-f453fe05d526>", line 3
#     int a[10],i,n,ele,pos;
#         ^
# SyntaxError: invalid syntax
