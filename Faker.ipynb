# %%
# !pip install faker

# %%
from faker import Faker
import time
fakegen = Faker()
methods = dir(fakegen)[::-1]


for i in methods:
    try:
        print(i, eval(f"fakegen.{i}()"), sep=" : ")
    except:
        print(i)
